# %% [markdown]
# # STAGE 1 DEV RESULT

# %%
# ── Cell 1: Mount Google Drive ────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Cell 2: Verify GPU ──────────────────────────────────────────────────────
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
# ── Cell 3: Paths — UPDATE DRIVE_ROOT to match your Shared Drive ──────────────
import os

# ── EDIT THESE ──
DRIVE_ROOT   = "/content/drive/Shareddrives/gec_thesis/gec_thesis"
DATASETS_DIR = f"{DRIVE_ROOT}/gec_gector_datasets_new"
TEST_DIR     = f"{DRIVE_ROOT}/gec_test_data"
CODE_DIR     = f"{DRIVE_ROOT}/gector_code_albert_updated"
STAGE1_CKPT  = f"{DRIVE_ROOT}/models/stage1/albert"   # folder with model_best.th
EVAL_OUT     = f"{DRIVE_ROOT}/models/eval/albert/stage1"  # evaluation outputs go here

# ── Local working dirs ──
WORK_DIR   = "/content/gector"
STAGE1_DIR = "/content/models/stage1/albert"

for d in [WORK_DIR, STAGE1_DIR, EVAL_OUT]:
    os.makedirs(d, exist_ok=True)

# ── Dataset paths ──
WI_TRAIN   = f"{DATASETS_DIR}/wi_train_gector.txt"
WI_DEV     = f"{DATASETS_DIR}/wi_dev_gector.txt"
VOCAB_PATH = f"{WORK_DIR}/data/output_vocabulary"

# ── Eval paths ──
GOLD_M2    = f"{TEST_DIR}/ABCN.dev.gold.bea19.m2"
DEV_ORIG   = "/content/ABCN.dev.orig.txt"
DEV_PRED   = "/content/dev_predictions.txt"
DEV_HYP_M2 = "/content/dev_hyp.m2"

print("✅ Paths defined!")
print(f"   DRIVE_ROOT  : {DRIVE_ROOT}")
print(f"   CODE_DIR    : {CODE_DIR}")
print(f"   STAGE1_CKPT : {STAGE1_CKPT}")
print(f"   EVAL_OUT    : {EVAL_OUT}")
# Out:
# ✅ Paths defined!
#    DRIVE_ROOT  : /content/drive/Shareddrives/gec_thesis/gec_thesis
#    CODE_DIR    : /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_albert_updated
#    STAGE1_CKPT : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage1/albert
#    EVAL_OUT    : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/stage1

# %%
# ── Cell 4: Verify all input files ────────────────────────────────────────────
import os

checks = [
    ("W&I Train",                      WI_TRAIN),
    ("W&I Dev",                        WI_DEV),
    ("Gold M2",                        GOLD_M2),
    ("Stage1 model_best.th",           os.path.join(STAGE1_CKPT, "model_best.th")),
    ("Code dir",                       CODE_DIR),
]

all_ok = True
for name, path in checks:
    exists = os.path.exists(path)
    print(f"  {'✅' if exists else '❌'} {name}: {path}")
    if not exists:
        all_ok = False

print()
print("✅ All files found — ready to proceed!" if all_ok else "❌ Fix missing files above before continuing.")
# Out:
#   ✅ W&I Train: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_train_gector.txt
#   ✅ W&I Dev: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_dev_gector.txt
#   ✅ Gold M2: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.dev.gold.bea19.m2
#   ✅ Stage1 model_best.th: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage1/albert/model_best.th
#   ✅ Code dir: /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_albert_updated
#
# ✅ All files found — ready to proceed!

# %%
# ── Cell 5: Copy gector_code_albert to local working dir ──────────────────────
import shutil, os

if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)
shutil.copytree(CODE_DIR, WORK_DIR)
print("✅ Code copied to", WORK_DIR)

for root, dirs, files in os.walk(WORK_DIR):
    for f in files:
        print(os.path.join(root, f).replace(WORK_DIR, ""))
# Out:
# ✅ Code copied to /content/gector
# /README_ALBERT.md
# /requirements.txt
# /predict.py
# /train.py
# /resume_training.py
# /utils/prepare_clc_fce_data.py
# /utils/preprocess_data.py
# /utils/helpers.py
# /data/verb-form-vocab.txt
# /data/output_vocabulary/d_tags.txt
# /data/output_vocabulary/labels.txt
# /data/output_vocabulary/non_padded_namespaces.txt
# /gector/gec_model.py
# /gector/seq2labels_model.py
# /gector/trainer.py
# /gector/datareader.py

# %%
# ── Cell 6: Patch gec_model.py for ALBERT ─────────────────────────────────────
new_gec_model = '''
import logging
import os
from time import time

import torch
from transformers import AutoTokenizer

from gector.seq2labels_model import Seq2Labels
from utils.helpers import PAD, UNK, get_target_sent_by_edits

logger = logging.getLogger(__file__)

MODEL_PATHS = {
    "bert":          "bert-base-cased",
    "distilbert":    "distilbert-base-uncased",
    "albert":        "albert-base-v2",
    "roberta":       "roberta-base",
    "gpt2":          "gpt2",
    "transformerxl": "transfo-xl-wt103",
    "xlnet":         "xlnet-base-cased",
    "tinybert":      "huawei-noah/TinyBERT_General_4L_312D",
    "mobilebert":    "google/mobilebert-uncased",
}


class SimpleVocab:
    def __init__(self, vocab_path):
        self.token2idx = {}
        self.idx2token = {}
        labels_file = os.path.join(vocab_path, "labels.txt")
        with open(labels_file, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                token = line.strip()
                self.token2idx[token] = idx
                self.idx2token[idx] = token

    def get_token_index(self, token, namespace=None):
        return self.token2idx.get(token, 0)

    def get_token_from_index(self, idx, namespace=None):
        return self.idx2token.get(idx, UNK)

    def __len__(self):
        return len(self.token2idx)


class GecBERTModel(object):
    def __init__(self, vocab_path=None, model_paths=None,
                 weigths=None,
                 max_len=50,
                 min_len=3,
                 lowercase_tokens=False,
                 log=False,
                 iterations=5,
                 min_probability=0.0,
                 model_name="albert",
                 special_tokens_fix=0,
                 is_ensemble=False,
                 min_error_probability=0.0,
                 confidence=0.0,
                 resolve_cycles=False):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.max_len = max_len
        self.min_len = min_len
        self.lowercase_tokens = lowercase_tokens
        self.min_probability = min_probability
        self.min_error_probability = min_error_probability
        self.log = log
        self.iterations = iterations
        self.confidence = confidence
        self.model_weights = list(map(float, weigths)) if weigths else [1] * len(model_paths)

        self.vocab = SimpleVocab(vocab_path)
        num_labels = len(self.vocab)

        weights_name = MODEL_PATHS.get(model_name, model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(weights_name)

        self.models = []
        for model_path in model_paths:
            model = Seq2Labels(
                encoder_name=weights_name,
                num_labels_classes=num_labels,
                num_detect_classes=4,
                confidence=confidence,
                special_tokens_fix=0,
                tune_bert=False,
            ).to(self.device)
            state = torch.load(model_path, map_location=self.device)
            model.load_state_dict(state)
            model.eval()
            self.models.append(model)

        print(f"✅ Loaded {len(self.models)} model(s) on {self.device}")

    def preprocess(self, token_batch):
        seq_lens = [len(s) for s in token_batch if s]
        if not seq_lens:
            return None

        all_input_ids, all_attention_masks, all_offsets = [], [], []

        for sequence in token_batch:
            tokens = sequence[:self.max_len - 1]
            words  = ["$START"] + tokens

            input_ids = []
            offsets   = []
            for word in words:
                word_ids = self.tokenizer.encode(word, add_special_tokens=False)
                if not word_ids:
                    word_ids = [self.tokenizer.unk_token_id]
                offsets.append(len(input_ids))
                input_ids.extend(word_ids)

            cls_id    = self.tokenizer.cls_token_id
            sep_id    = self.tokenizer.sep_token_id
            input_ids = [cls_id] + input_ids + [sep_id]
            offsets   = [o + 1 for o in offsets]

            all_input_ids.append(input_ids)
            all_offsets.append(offsets)

        max_seq_len  = max(len(ids) for ids in all_input_ids)
        max_word_len = max(len(off) for off in all_offsets)
        pad_id = self.tokenizer.pad_token_id or 0

        padded_ids, attn_masks, padded_offsets = [], [], []
        for ids, offsets in zip(all_input_ids, all_offsets):
            pad_len = max_seq_len - len(ids)
            padded_ids.append(ids + [pad_id] * pad_len)
            attn_masks.append([1] * len(ids) + [0] * pad_len)
            off_pad = max_word_len - len(offsets)
            padded_offsets.append(offsets + [0] * off_pad)

        return {
            "input_ids":      torch.tensor(padded_ids,     dtype=torch.long).to(self.device),
            "attention_mask": torch.tensor(attn_masks,     dtype=torch.long).to(self.device),
            "offsets":        torch.tensor(padded_offsets, dtype=torch.long).to(self.device),
        }

    def predict(self, batch):
        t0 = time()
        predictions = []
        for model in self.models:
            with torch.no_grad():
                output = model.forward(
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    offsets=batch["offsets"],
                )
            predictions.append(output)
        probs, idx, error_probs = self._convert(predictions)
        if self.log:
            print(f"Inference time {time() - t0:.2f}s")
        return probs, idx, error_probs

    def _convert(self, data):
        all_class_probs = torch.zeros_like(data[0]["class_probabilities_labels"])
        error_probs     = torch.zeros_like(data[0]["max_error_probability"])
        for output, weight in zip(data, self.model_weights):
            all_class_probs += weight * output["class_probabilities_labels"] / sum(self.model_weights)
            error_probs     += weight * output["max_error_probability"]      / sum(self.model_weights)
        max_vals = torch.max(all_class_probs, dim=-1)
        return max_vals[0].tolist(), max_vals[1].tolist(), error_probs.tolist()

    def get_token_action(self, token, index, prob, sugg_token):
        if prob < self.min_probability or sugg_token in [UNK, PAD, "$KEEP"]:
            return None
        if sugg_token.startswith("$REPLACE_") or sugg_token.startswith("$TRANSFORM_") or sugg_token == "$DELETE":
            start_pos, end_pos = index, index + 1
        elif sugg_token.startswith("$APPEND_") or sugg_token.startswith("$MERGE_"):
            start_pos = end_pos = index + 1
        else:
            return None
        sugg_token_clear = "" if sugg_token == "$DELETE" else (
            sugg_token if sugg_token.startswith("$TRANSFORM_") or sugg_token.startswith("$MERGE_")
            else sugg_token[sugg_token.index("_") + 1:]
        )
        return start_pos - 1, end_pos - 1, sugg_token_clear, prob

    def postprocess_batch(self, batch, all_probabilities, all_idxs, error_probs):
        all_results = []
        noop_index = self.vocab.get_token_index("$KEEP", "labels")
        for tokens, probabilities, idxs, error_prob in zip(
                batch, all_probabilities, all_idxs, error_probs):
            length = min(len(tokens), self.max_len)
            if max(idxs) == 0 or error_prob < self.min_error_probability:
                all_results.append(tokens)
                continue
            edits = []
            for i in range(length):
                token = tokens[i - 1]
                if idxs[i] == noop_index:
                    continue
                sugg_token = self.vocab.get_token_from_index(idxs[i], "labels")
                action = self.get_token_action(token, i, probabilities[i], sugg_token)
                if action:
                    edits.append(action)
            all_results.append(get_target_sent_by_edits(tokens, edits))
        return all_results

    def update_final_batch(self, final_batch, pred_ids, pred_batch, prev_preds_dict):
        new_pred_ids  = []
        total_updated = 0
        for i, orig_id in enumerate(pred_ids):
            orig       = final_batch[orig_id]
            pred       = pred_batch[i]
            prev_preds = prev_preds_dict[orig_id]
            if orig != pred and pred not in prev_preds:
                final_batch[orig_id] = pred
                new_pred_ids.append(orig_id)
                prev_preds_dict[orig_id].append(pred)
                total_updated += 1
            elif orig != pred and pred in prev_preds:
                final_batch[orig_id] = pred
                total_updated += 1
        return final_batch, new_pred_ids, total_updated

    def handle_batch(self, full_batch):
        final_batch     = full_batch[:]
        batch_size      = len(full_batch)
        prev_preds_dict = {i: [final_batch[i]] for i in range(batch_size)}
        short_ids       = [i for i in range(batch_size) if len(full_batch[i]) < self.min_len]
        pred_ids        = [i for i in range(batch_size) if i not in short_ids]
        total_updates   = 0

        for n_iter in range(self.iterations):
            orig_batch = [final_batch[i] for i in pred_ids]
            sequences  = self.preprocess(orig_batch)
            if not sequences:
                break
            probabilities, idxs, error_probs = self.predict(sequences)
            pred_batch = self.postprocess_batch(orig_batch, probabilities, idxs, error_probs)
            if self.log:
                print(f"Iteration {n_iter + 1}: {round(100*len(pred_ids)/batch_size, 1)}% of sentences active")
            final_batch, pred_ids, cnt = self.update_final_batch(
                final_batch, pred_ids, pred_batch, prev_preds_dict)
            total_updates += cnt
            if not pred_ids:
                break

        return final_batch, total_updates
'''

import os
with open(f"{WORK_DIR}/gector/gec_model.py", "w") as f:
    f.write(new_gec_model)
print("✅ gec_model.py patched for ALBERT!")
# Out:
# ✅ gec_model.py patched for ALBERT!

# %%
# ── Cell 7: Restore Stage 1 checkpoint from Drive ────────────────────────────────
import shutil, os

os.makedirs(STAGE1_DIR, exist_ok=True)

print("Restoring Stage 1 best model from Drive...")
src = os.path.join(STAGE1_CKPT, "model_best.th")
dst = os.path.join(STAGE1_DIR, "model_best.th")
if os.path.exists(src):
    shutil.copy(src, dst)
    size = os.path.getsize(dst) / 1e6
    print(f"  ✅ model_best.th ({size:.1f} MB)")
else:
    print(f"  ❌ Not found: {src}")

print("\n✅ Model ready for inference!")
# Out:
# Restoring Stage 1 best model from Drive...
#   ✅ model_best.th (62.1 MB)
#
# ✅ Model ready for inference!

# %%
# ── Cell 8: Extract dev orig sentences from Gold M2 ──────────────────────────
import os

print("Extracting dev orig from gold m2...")
with open(GOLD_M2, encoding='utf-8') as f_in, \
     open(DEV_ORIG, 'w', encoding='utf-8') as f_out:
    for line in f_in:
        if line.startswith("S "):
            f_out.write(line[2:])

with open(DEV_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Extracted {count} source sentences → {DEV_ORIG}")
# Out:
# Extracting dev orig from gold m2...
# ✅ Extracted 4384 source sentences → /content/ABCN.dev.orig.txt

# %%
# ── Cell 9: Run inference on dev set ─────────────────────────────────────────
import subprocess
import os
import sys

os.chdir(WORK_DIR)

predict_cmd = [
    "python", "predict.py",
    "--model_path",           f"{STAGE1_DIR}/model_best.th",
    "--vocab_path",           VOCAB_PATH,
    "--input_file",           DEV_ORIG,
    "--output_file",          DEV_PRED,
    "--transformer_model",    "albert",
    "--iteration_count",      "5",
    "--min_error_probability","0.1",
    "--min_probability",      "0.0",
    "--additional_confidence","0.0",
    "--special_tokens_fix",   "0",
    "--lowercase_tokens",     "1",
]

print("Running inference on dev set (ALBERT)...")
print(f"  Input : {DEV_ORIG}")
print(f"  Output: {DEV_PRED}")
print()

process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

for line in process.stdout:
    print(line, end="", flush=True)

process.wait()
print("\n✅ Inference done!")

# ── Save dev predictions to Drive ──
import shutil
shutil.copy(DEV_PRED, os.path.join(EVAL_OUT, "dev_predictions.txt"))
print(f"✅ dev_predictions.txt saved to Drive: {EVAL_OUT}")
# Out:
# Running inference on dev set (ALBERT)...
#   Input : /content/ABCN.dev.orig.txt
#   Output: /content/dev_predictions.txt
#
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/25 [00:00<?, ?it/s]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 19508.39it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 5974.79it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 5691.05it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 4744.69it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 4830.29it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 4343.43it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 3359.47it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 3152.43it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 3341.01it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 3128.21it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 2105.93it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 1991.75it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 2149.04it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 2085.68it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 2234.58it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 2164.38it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 2291.55it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 2233.12it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 2146.85it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 2096.10it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 2090.50it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 2042.65it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 2010.53it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 1977.98it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1871.88it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1846.52it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1919.65it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1898.24it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1986.13it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1924.11it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1993.91it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1964.20it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 2026.75it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 2009.96it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1870.93it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1847.94it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1902.04it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1877.04it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1876.14it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1852.85it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1901.64it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1878.97it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1874.59it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1856.86it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1910.77it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1893.03it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1945.03it/s, Materializing param=pooler.bias]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1931.23it/s, Materializing param=pooler.bias]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1984.89it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1967.86it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1938.43it/s, Materializing param=pooler.weight]
# AlbertModel LOAD REPORT from: albert-base-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# predictions.LayerNorm.bias   | UNEXPECTED |  |
# predictions.bias             | UNEXPECTED |  |
# predictions.decoder.bias     | UNEXPECTED |  |
# predictions.LayerNorm.weight | UNEXPECTED |  |
# predictions.dense.weight     | UNEXPECTED |  |
# predictions.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 2589
#
# ✅ Inference done!
# ✅ dev_predictions.txt saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/stage1

# %%
# ── Cell 10: Dependencies ──────────────────────────────────────
import os
os.system("pip install errant -q")
os.system("python -m spacy download en -q")
print("✅ ERRANT installed!")
# Out:
# ✅ ERRANT installed!

# %%
# ── Cell 11: ERRANT annotation + scoring ──────────────────────────────────────
import os

print("Running ERRANT annotation on dev predictions...")
os.system(f"errant_parallel -orig {DEV_ORIG} -cor {DEV_PRED} -out {DEV_HYP_M2}")

if os.path.exists(DEV_HYP_M2):
    print("✅ dev_hyp.m2 created!")
else:
    print("❌ dev_hyp.m2 not created")

with open(DEV_HYP_M2) as f:
    hyp_count = sum(1 for line in f if line.startswith("S "))
with open(GOLD_M2) as f:
    gold_count = sum(1 for line in f if line.startswith("S "))

print(f"hyp sentences:  {hyp_count}")
print(f"gold sentences: {gold_count}")

if hyp_count != gold_count:
    print("❌ Sentence count mismatch!")
else:
    print("\n========================================")
    print("ERRANT Scores on BEA-2019 Dev Set:")
    print("(Precision / Recall / F0.5)")
    print("========================================")
    result = os.popen(f"errant_compare -hyp {DEV_HYP_M2} -ref {GOLD_M2} 2>&1").read()
    print(result)

# ── Save dev_hyp.m2 to Drive ──
import shutil
shutil.copy(DEV_HYP_M2, os.path.join(EVAL_OUT, "dev_hyp.m2"))
print(f"✅ dev_hyp.m2 saved to Drive: {EVAL_OUT}")
# Out:
# Running ERRANT annotation on dev predictions...
# ✅ dev_hyp.m2 created!
# hyp sentences:  4384
# gold sentences: 4384
#
# ========================================
# ERRANT Scores on BEA-2019 Dev Set:
# (Precision / Recall / F0.5)
# ========================================
#
# =========== Span-Based Correction ============
# TP	FP	FN	Prec	Rec	F0.5
# 1140	2081	6321	0.3539	0.1528	0.2802
# ==============================================
#
#
# ✅ dev_hyp.m2 saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/stage1

# %% [markdown]
# # STAGE 2 DEV RESULT

# %%
# ── Cell 1: Mount Google Drive ────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Cell 2: Verify GPU ──────────────────────────────────────────────────────
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
# ── Cell 3: Paths — UPDATE DRIVE_ROOT to match your Shared Drive ──────────────
import os

# ── EDIT THESE ──
DRIVE_ROOT   = "/content/drive/Shareddrives/gec_thesis/gec_thesis"
DATASETS_DIR = f"{DRIVE_ROOT}/gec_gector_datasets_new"
TEST_DIR     = f"{DRIVE_ROOT}/gec_test_data"
CODE_DIR     = f"{DRIVE_ROOT}/gector_code_albert_updated"
STAGE2_CKPT  = f"{DRIVE_ROOT}/models/stage2/albert"   # folder with model_best.th
EVAL_OUT     = f"{DRIVE_ROOT}/models/eval/albert/stage2"  # evaluation outputs go here

# ── Local working dirs ──
WORK_DIR   = "/content/gector"


STAGE2_DIR = "/content/models/stage2/albert"

for d in [WORK_DIR, STAGE2_DIR, EVAL_OUT]:
    os.makedirs(d, exist_ok=True)

# ── Dataset paths ──
WI_TRAIN   = f"{DATASETS_DIR}/wi_train_gector.txt"
WI_DEV     = f"{DATASETS_DIR}/wi_dev_gector.txt"
VOCAB_PATH = f"{WORK_DIR}/data/output_vocabulary"

# ── Eval paths ──
GOLD_M2     = f"{TEST_DIR}/ABCN.dev.gold.bea19.m2"
DEV_ORIG    = "/content/ABCN.dev.orig.txt"
DEV_PRED    = "/content/dev_predictions.txt"
DEV_HYP_M2  = "/content/dev_hyp.m2"

print("✅ Paths defined!")
print(f"   DRIVE_ROOT  : {DRIVE_ROOT}")
print(f"   CODE_DIR    : {CODE_DIR}")
print(f"   STAGE2_CKPT : {STAGE2_CKPT}")
print(f"   EVAL_OUT    : {EVAL_OUT}")
# Out:
# ✅ Paths defined!
#    DRIVE_ROOT  : /content/drive/Shareddrives/gec_thesis/gec_thesis
#    CODE_DIR    : /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_albert_updated
#    STAGE2_CKPT : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage2/albert
#    EVAL_OUT    : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/stage2

# %%
# ── Cell 4: Verify all input files ────────────────────────────────────────────
import os

checks = [
    ("W&I Train",                      WI_TRAIN),
    ("W&I Dev",                        WI_DEV),
    ("Gold M2",                        GOLD_M2),
    ("Stage1 model_best.th",           os.path.join(STAGE2_CKPT, "model_best.th")),
    ("Code dir",                       CODE_DIR),
]

all_ok = True
for name, path in checks:
    exists = os.path.exists(path)
    print(f"  {'✅' if exists else '❌'} {name}: {path}")
    if not exists:
        all_ok = False

print()
print("✅ All files found — ready to proceed!" if all_ok else "❌ Fix missing files above before continuing.")
# Out:
#   ✅ W&I Train: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_train_gector.txt
#   ✅ W&I Dev: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_dev_gector.txt
#   ✅ Gold M2: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.dev.gold.bea19.m2
#   ✅ Stage1 model_best.th: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage2/albert/model_best.th
#   ✅ Code dir: /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_albert_updated
#
# ✅ All files found — ready to proceed!

# %%
# ── Cell 5: Copy gector_code_albert to local working dir ──────────────────────
import shutil, os

if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)
shutil.copytree(CODE_DIR, WORK_DIR)
print("✅ Code copied to", WORK_DIR)

for root, dirs, files in os.walk(WORK_DIR):
    for f in files:
        print(os.path.join(root, f).replace(WORK_DIR, ""))
# Out:
# ✅ Code copied to /content/gector
# /README_ALBERT.md
# /requirements.txt
# /predict.py
# /train.py
# /resume_training.py
# /utils/prepare_clc_fce_data.py
# /utils/preprocess_data.py
# /utils/helpers.py
# /data/verb-form-vocab.txt
# /data/output_vocabulary/d_tags.txt
# /data/output_vocabulary/labels.txt
# /data/output_vocabulary/non_padded_namespaces.txt
# /gector/gec_model.py
# /gector/seq2labels_model.py
# /gector/trainer.py
# /gector/datareader.py

# %%
# ── Cell 6: Patch gec_model.py for ALBERT ─────────────────────────────────────
new_gec_model = '''
import logging
import os
from time import time

import torch
from transformers import AutoTokenizer

from gector.seq2labels_model import Seq2Labels
from utils.helpers import PAD, UNK, get_target_sent_by_edits

logger = logging.getLogger(__file__)

MODEL_PATHS = {
    "bert":          "bert-base-cased",
    "distilbert":    "distilbert-base-uncased",
    "albert":        "albert-base-v2",
    "roberta":       "roberta-base",
    "gpt2":          "gpt2",
    "transformerxl": "transfo-xl-wt103",
    "xlnet":         "xlnet-base-cased",
    "tinybert":      "huawei-noah/TinyBERT_General_4L_312D",
    "mobilebert":    "google/mobilebert-uncased",
}


class SimpleVocab:
    def __init__(self, vocab_path):
        self.token2idx = {}
        self.idx2token = {}
        labels_file = os.path.join(vocab_path, "labels.txt")
        with open(labels_file, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                token = line.strip()
                self.token2idx[token] = idx
                self.idx2token[idx] = token

    def get_token_index(self, token, namespace=None):
        return self.token2idx.get(token, 0)

    def get_token_from_index(self, idx, namespace=None):
        return self.idx2token.get(idx, UNK)

    def __len__(self):
        return len(self.token2idx)


class GecBERTModel(object):
    def __init__(self, vocab_path=None, model_paths=None,
                 weigths=None,
                 max_len=50,
                 min_len=3,
                 lowercase_tokens=False,
                 log=False,
                 iterations=5,
                 min_probability=0.0,
                 model_name="albert",
                 special_tokens_fix=0,
                 is_ensemble=False,
                 min_error_probability=0.0,
                 confidence=0.0,
                 resolve_cycles=False):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.max_len = max_len
        self.min_len = min_len
        self.lowercase_tokens = lowercase_tokens
        self.min_probability = min_probability
        self.min_error_probability = min_error_probability
        self.log = log
        self.iterations = iterations
        self.confidence = confidence
        self.model_weights = list(map(float, weigths)) if weigths else [1] * len(model_paths)

        self.vocab = SimpleVocab(vocab_path)
        num_labels = len(self.vocab)

        weights_name = MODEL_PATHS.get(model_name, model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(weights_name)

        self.models = []
        for model_path in model_paths:
            model = Seq2Labels(
                encoder_name=weights_name,
                num_labels_classes=num_labels,
                num_detect_classes=4,
                confidence=confidence,
                special_tokens_fix=0,
                tune_bert=False,
            ).to(self.device)
            state = torch.load(model_path, map_location=self.device)
            model.load_state_dict(state)
            model.eval()
            self.models.append(model)

        print(f"✅ Loaded {len(self.models)} model(s) on {self.device}")

    def preprocess(self, token_batch):
        seq_lens = [len(s) for s in token_batch if s]
        if not seq_lens:
            return None

        all_input_ids, all_attention_masks, all_offsets = [], [], []

        for sequence in token_batch:
            tokens = sequence[:self.max_len - 1]
            words  = ["$START"] + tokens

            input_ids = []
            offsets   = []
            for word in words:
                word_ids = self.tokenizer.encode(word, add_special_tokens=False)
                if not word_ids:
                    word_ids = [self.tokenizer.unk_token_id]
                offsets.append(len(input_ids))
                input_ids.extend(word_ids)

            cls_id    = self.tokenizer.cls_token_id
            sep_id    = self.tokenizer.sep_token_id
            input_ids = [cls_id] + input_ids + [sep_id]
            offsets   = [o + 1 for o in offsets]

            all_input_ids.append(input_ids)
            all_offsets.append(offsets)

        max_seq_len  = max(len(ids) for ids in all_input_ids)
        max_word_len = max(len(off) for off in all_offsets)
        pad_id = self.tokenizer.pad_token_id or 0

        padded_ids, attn_masks, padded_offsets = [], [], []
        for ids, offsets in zip(all_input_ids, all_offsets):
            pad_len = max_seq_len - len(ids)
            padded_ids.append(ids + [pad_id] * pad_len)
            attn_masks.append([1] * len(ids) + [0] * pad_len)
            off_pad = max_word_len - len(offsets)
            padded_offsets.append(offsets + [0] * off_pad)

        return {
            "input_ids":      torch.tensor(padded_ids,     dtype=torch.long).to(self.device),
            "attention_mask": torch.tensor(attn_masks,     dtype=torch.long).to(self.device),
            "offsets":        torch.tensor(padded_offsets, dtype=torch.long).to(self.device),
        }

    def predict(self, batch):
        t0 = time()
        predictions = []
        for model in self.models:
            with torch.no_grad():
                output = model.forward(
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    offsets=batch["offsets"],
                )
            predictions.append(output)
        probs, idx, error_probs = self._convert(predictions)
        if self.log:
            print(f"Inference time {time() - t0:.2f}s")
        return probs, idx, error_probs

    def _convert(self, data):
        all_class_probs = torch.zeros_like(data[0]["class_probabilities_labels"])
        error_probs     = torch.zeros_like(data[0]["max_error_probability"])
        for output, weight in zip(data, self.model_weights):
            all_class_probs += weight * output["class_probabilities_labels"] / sum(self.model_weights)
            error_probs     += weight * output["max_error_probability"]      / sum(self.model_weights)
        max_vals = torch.max(all_class_probs, dim=-1)
        return max_vals[0].tolist(), max_vals[1].tolist(), error_probs.tolist()

    def get_token_action(self, token, index, prob, sugg_token):
        if prob < self.min_probability or sugg_token in [UNK, PAD, "$KEEP"]:
            return None
        if sugg_token.startswith("$REPLACE_") or sugg_token.startswith("$TRANSFORM_") or sugg_token == "$DELETE":
            start_pos, end_pos = index, index + 1
        elif sugg_token.startswith("$APPEND_") or sugg_token.startswith("$MERGE_"):
            start_pos = end_pos = index + 1
        else:
            return None
        sugg_token_clear = "" if sugg_token == "$DELETE" else (
            sugg_token if sugg_token.startswith("$TRANSFORM_") or sugg_token.startswith("$MERGE_")
            else sugg_token[sugg_token.index("_") + 1:]
        )
        return start_pos - 1, end_pos - 1, sugg_token_clear, prob

    def postprocess_batch(self, batch, all_probabilities, all_idxs, error_probs):
        all_results = []
        noop_index = self.vocab.get_token_index("$KEEP", "labels")
        for tokens, probabilities, idxs, error_prob in zip(
                batch, all_probabilities, all_idxs, error_probs):
            length = min(len(tokens), self.max_len)
            if max(idxs) == 0 or error_prob < self.min_error_probability:
                all_results.append(tokens)
                continue
            edits = []
            for i in range(length):
                token = tokens[i - 1]
                if idxs[i] == noop_index:
                    continue
                sugg_token = self.vocab.get_token_from_index(idxs[i], "labels")
                action = self.get_token_action(token, i, probabilities[i], sugg_token)
                if action:
                    edits.append(action)
            all_results.append(get_target_sent_by_edits(tokens, edits))
        return all_results

    def update_final_batch(self, final_batch, pred_ids, pred_batch, prev_preds_dict):
        new_pred_ids  = []
        total_updated = 0
        for i, orig_id in enumerate(pred_ids):
            orig       = final_batch[orig_id]
            pred       = pred_batch[i]
            prev_preds = prev_preds_dict[orig_id]
            if orig != pred and pred not in prev_preds:
                final_batch[orig_id] = pred
                new_pred_ids.append(orig_id)
                prev_preds_dict[orig_id].append(pred)
                total_updated += 1
            elif orig != pred and pred in prev_preds:
                final_batch[orig_id] = pred
                total_updated += 1
        return final_batch, new_pred_ids, total_updated

    def handle_batch(self, full_batch):
        final_batch     = full_batch[:]
        batch_size      = len(full_batch)
        prev_preds_dict = {i: [final_batch[i]] for i in range(batch_size)}
        short_ids       = [i for i in range(batch_size) if len(full_batch[i]) < self.min_len]
        pred_ids        = [i for i in range(batch_size) if i not in short_ids]
        total_updates   = 0

        for n_iter in range(self.iterations):
            orig_batch = [final_batch[i] for i in pred_ids]
            sequences  = self.preprocess(orig_batch)
            if not sequences:
                break
            probabilities, idxs, error_probs = self.predict(sequences)
            pred_batch = self.postprocess_batch(orig_batch, probabilities, idxs, error_probs)
            if self.log:
                print(f"Iteration {n_iter + 1}: {round(100*len(pred_ids)/batch_size, 1)}% of sentences active")
            final_batch, pred_ids, cnt = self.update_final_batch(
                final_batch, pred_ids, pred_batch, prev_preds_dict)
            total_updates += cnt
            if not pred_ids:
                break

        return final_batch, total_updates
'''

import os
with open(f"{WORK_DIR}/gector/gec_model.py", "w") as f:
    f.write(new_gec_model)
print("✅ gec_model.py patched for ALBERT!")
# Out:
# ✅ gec_model.py patched for ALBERT!

# %%
# ── Cell 6: Restore Stage 2 checkpoint from Drive ────────────────────────────────
import shutil, os

os.makedirs(STAGE2_DIR, exist_ok=True)

print("Restoring Stage 2 best model from Drive...")
src = os.path.join(STAGE2_CKPT, "model_best.th")
dst = os.path.join(STAGE2_DIR, "model_best.th")
if os.path.exists(src):
    shutil.copy(src, dst)
    size = os.path.getsize(dst) / 1e6
    print(f"  ✅ model_best.th ({size:.1f} MB)")
else:
    print(f"  ❌ Not found: {src}")

print("\n✅ Model ready for inference!")
# Out:
# Restoring Stage 2 best model from Drive...
#   ✅ model_best.th (62.1 MB)
#
# ✅ Model ready for inference!

# %%
# ── Cell 13: Extract dev orig sentences from Gold M2 ──────────────────────────
import os

print("Extracting dev orig from gold m2...")
with open(GOLD_M2, encoding='utf-8') as f_in, \
     open(DEV_ORIG, 'w', encoding='utf-8') as f_out:
    for line in f_in:
        if line.startswith("S "):
            f_out.write(line[2:])

with open(DEV_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Extracted {count} source sentences → {DEV_ORIG}")
# Out:
# Extracting dev orig from gold m2...
# ✅ Extracted 4384 source sentences → /content/ABCN.dev.orig.txt

# %%
import os
os.system("pip install errant -q")
os.system("python -m spacy download en -q")
print("✅ ERRANT installed!")
# Out:
# ✅ ERRANT installed!

# %%
# ── Cell 14: Run inference on dev set ─────────────────────────────────────────
import subprocess
import os
import sys

os.chdir(WORK_DIR)

predict_cmd = [
    "python", "predict.py",
    "--model_path",           f"{STAGE2_DIR}/model_best.th",
    "--vocab_path",           VOCAB_PATH,
    "--input_file",           DEV_ORIG,
    "--output_file",          DEV_PRED,
    "--transformer_model",    "albert",
    "--iteration_count",      "5",
    "--min_error_probability","0.1",
    "--min_probability",      "0.0",
    "--additional_confidence","0.0",
    "--special_tokens_fix",   "0",
    "--lowercase_tokens",     "1",
]

print("Running inference on dev set (ALBERT)...")
print(f"  Input : {DEV_ORIG}")
print(f"  Output: {DEV_PRED}")
print()

process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

for line in process.stdout:
    print(line, end="", flush=True)

process.wait()
print("\n✅ Inference done!")

# ── Save dev predictions to Drive ──
import shutil
shutil.copy(DEV_PRED, os.path.join(EVAL_OUT, "dev_predictions.txt"))
print(f"✅ dev_predictions.txt saved to Drive: {EVAL_OUT}")
# Out:
# Running inference on dev set (ALBERT)...
#   Input : /content/ABCN.dev.orig.txt
#   Output: /content/dev_predictions.txt
#
#
# Loading weights:   0%|          | 0/25 [00:00<?, ?it/s]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 17623.13it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 7345.54it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 6808.94it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 5618.63it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 1136.67it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 1082.68it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 1241.56it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 1190.30it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 1374.01it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 1256.31it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 1176.03it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 1145.41it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 1271.22it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 1243.65it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 1294.29it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 1269.17it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 1376.44it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 1348.60it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 1423.05it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 1398.43it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 1366.51it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 1346.80it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 1375.82it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 1357.60it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1425.14it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1404.69it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1470.58it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1446.81it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1478.95it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1462.25it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1513.75it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1496.96it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 1571.73it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 1562.57it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1634.32it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1622.69it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1693.48it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1685.46it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1759.87it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1747.81it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1802.38it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1792.51it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1852.79it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1839.64it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1899.82it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1890.14it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1952.81it/s, Materializing param=pooler.bias]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1939.19it/s, Materializing param=pooler.bias]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1998.35it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1982.11it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1960.65it/s, Materializing param=pooler.weight]
# AlbertModel LOAD REPORT from: albert-base-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# predictions.LayerNorm.bias   | UNEXPECTED |  |
# predictions.dense.weight     | UNEXPECTED |  |
# predictions.decoder.bias     | UNEXPECTED |  |
# predictions.dense.bias       | UNEXPECTED |  |
# predictions.bias             | UNEXPECTED |  |
# predictions.LayerNorm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 641
#
# ✅ Inference done!
# ✅ dev_predictions.txt saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/stage2

# %%
# ── Cell 11: ERRANT annotation + scoring ──────────────────────────────────────
import os

print("Running ERRANT annotation on dev predictions...")
os.system(f"errant_parallel -orig {DEV_ORIG} -cor {DEV_PRED} -out {DEV_HYP_M2}")

if os.path.exists(DEV_HYP_M2):
    print("✅ dev_hyp.m2 created!")
else:
    print("❌ dev_hyp.m2 not created")

with open(DEV_HYP_M2) as f:
    hyp_count = sum(1 for line in f if line.startswith("S "))
with open(GOLD_M2) as f:
    gold_count = sum(1 for line in f if line.startswith("S "))

print(f"hyp sentences:  {hyp_count}")
print(f"gold sentences: {gold_count}")

if hyp_count != gold_count:
    print("❌ Sentence count mismatch!")
else:
    print("\n========================================")
    print("ERRANT Scores on BEA-2019 Dev Set:")
    print("(Precision / Recall / F0.5)")
    print("========================================")
    result = os.popen(f"errant_compare -hyp {DEV_HYP_M2} -ref {GOLD_M2} 2>&1").read()
    print(result)

# ── Save dev_hyp.m2 to Drive ──
import shutil
shutil.copy(DEV_HYP_M2, os.path.join(EVAL_OUT, "dev_hyp.m2"))
print(f"✅ dev_hyp.m2 saved to Drive: {EVAL_OUT}")
# Out:
# Running ERRANT annotation on dev predictions...
# ✅ dev_hyp.m2 created!
# hyp sentences:  4384
# gold sentences: 4384
#
# ========================================
# ERRANT Scores on BEA-2019 Dev Set:
# (Precision / Recall / F0.5)
# ========================================
#
# =========== Span-Based Correction ============
# TP	FP	FN	Prec	Rec	F0.5
# 414	289	7047	0.5889	0.0555	0.2015
# ==============================================
#
#
# ✅ dev_hyp.m2 saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/stage2

# %% [markdown]
# # STAGE 3 DEV RESULT

# %%
# ── Cell 1: Mount Google Drive ────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Cell 2: Verify GPU ──────────────────────────────────────────────────────
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
# ── Cell 3: Paths — UPDATE DRIVE_ROOT to match your Shared Drive ──────────────
import os

# ── EDIT THESE ──
DRIVE_ROOT   = "/content/drive/Shareddrives/gec_thesis/gec_thesis"
DATASETS_DIR = f"{DRIVE_ROOT}/gec_gector_datasets_new"
TEST_DIR     = f"{DRIVE_ROOT}/gec_test_data"
CODE_DIR     = f"{DRIVE_ROOT}/gector_code_albert_updated"
STAGE3_CKPT  = f"{DRIVE_ROOT}/models/stage3/albert"   # folder with model_best.th
EVAL_OUT     = f"{DRIVE_ROOT}/models/eval/albert"         # evaluation outputs go here

# ── Local working dirs ──
WORK_DIR   = "/content/gector"
STAGE3_DIR = "/content/models/stage3/albert"

for d in [WORK_DIR, STAGE3_DIR, EVAL_OUT]:
    os.makedirs(d, exist_ok=True)

# ── Dataset paths ──
WI_TRAIN   = f"{DATASETS_DIR}/wi_train_gector.txt"
WI_DEV     = f"{DATASETS_DIR}/wi_dev_gector.txt"
VOCAB_PATH = f"{WORK_DIR}/data/output_vocabulary"

# ── Eval paths ──
GOLD_M2     = f"{TEST_DIR}/ABCN.dev.gold.bea19.m2"
DEV_ORIG    = "/content/ABCN.dev.orig.txt"
DEV_PRED    = "/content/dev_predictions.txt"
DEV_HYP_M2  = "/content/dev_hyp.m2"

print("✅ Paths defined!")
print(f"   DRIVE_ROOT  : {DRIVE_ROOT}")
print(f"   CODE_DIR    : {CODE_DIR}")
print(f"   STAGE3_CKPT : {STAGE3_CKPT}")
print(f"   EVAL_OUT    : {EVAL_OUT}")
# Out:
# ✅ Paths defined!
#    DRIVE_ROOT  : /content/drive/Shareddrives/gec_thesis/gec_thesis
#    CODE_DIR    : /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_albert_updated
#    STAGE3_CKPT : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage3/albert
#    EVAL_OUT    : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert

# %%
# ── Inference Profiling Utilities ───────────────────────────────────────────────
import torch, time as _time_mod

def _gpu_mem_mb():
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        alloc  = torch.cuda.memory_allocated()  / 1e6
        reserv = torch.cuda.memory_reserved()   / 1e6
        total  = torch.cuda.get_device_properties(0).total_memory / 1e6
        return alloc, reserv, total
    return 0.0, 0.0, 0.0

def _count_params(model_path):
    """Count total parameters from a saved .th state dict."""
    try:
        state = torch.load(model_path, map_location="cpu")
        total = sum(p.numel() for p in state.values() if hasattr(p, "numel"))
        return total
    except Exception as e:
        print(f"  ⚠  Could not count params: {e}")
        return -1

def print_inference_profile(label, start_time, end_time, sentence_count, model_path=None):
    elapsed  = end_time - start_time
    per_sent = elapsed / sentence_count if sentence_count > 0 else 0
    alloc, reserv, total_vram = _gpu_mem_mb()

    print(f"\n{'='*58}")
    print(f"  📊  Inference Profile — {label}")
    print(f"{'='*58}")
    print(f"  ⏱  Total inference time : {elapsed:.2f} s")
    print(f"  ⏱  Per-sentence latency : {per_sent*1000:.2f} ms  ({sentence_count} sentences)")
    print(f"  🖥  GPU RAM allocated    : {alloc:.1f} MB")
    print(f"  🖥  GPU RAM reserved     : {reserv:.1f} MB")
    print(f"  🖥  GPU VRAM total       : {total_vram:.1f} MB")
    if model_path:
        params = _count_params(model_path)
        if params >= 0:
            print(f"  🔢  Model parameters     : {params:,}  ({params/1e6:.2f} M)")
    print(f"{'='*58}\n")

print("✅ Profiling utilities loaded (GPU RAM / inference time / param count)!")
# Out:
# ✅ Profiling utilities loaded (GPU RAM / inference time / param count)!

# %%
# ── Cell 4: Verify all input files ────────────────────────────────────────────
import os

checks = [
    ("W&I Train",                      WI_TRAIN),
    ("W&I Dev",                        WI_DEV),
    ("Gold M2",                        GOLD_M2),
    ("Stage3 model_best.th",           os.path.join(STAGE3_CKPT, "model_best.th")),
    ("Code dir",                       CODE_DIR),
]

all_ok = True
for name, path in checks:
    exists = os.path.exists(path)
    print(f"  {'✅' if exists else '❌'} {name}: {path}")
    if not exists:
        all_ok = False

print()
print("✅ All files found — ready to proceed!" if all_ok else "❌ Fix missing files above before continuing.")
# Out:
#   ✅ W&I Train: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_train_gector.txt
#   ✅ W&I Dev: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_dev_gector.txt
#   ✅ Gold M2: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.dev.gold.bea19.m2
#   ✅ Stage3 model_best.th: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage3/albert/model_best.th
#   ✅ Code dir: /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_albert_updated
#
# ✅ All files found — ready to proceed!

# %%
# ── Cell 5: Copy gector_code_albert to local working dir ──────────────────────
import shutil, os

if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)
shutil.copytree(CODE_DIR, WORK_DIR)
print("✅ Code copied to", WORK_DIR)

for root, dirs, files in os.walk(WORK_DIR):
    for f in files:
        print(os.path.join(root, f).replace(WORK_DIR, ""))
# Out:
# ✅ Code copied to /content/gector
# /predict.py
# /README_ALBERT.md
# /resume_training.py
# /requirements.txt
# /train.py
# /gector/trainer.py
# /gector/datareader.py
# /gector/seq2labels_model.py
# /gector/gec_model.py
# /data/verb-form-vocab.txt
# /data/output_vocabulary/non_padded_namespaces.txt
# /data/output_vocabulary/labels.txt
# /data/output_vocabulary/d_tags.txt
# /utils/preprocess_data.py
# /utils/helpers.py
# /utils/prepare_clc_fce_data.py

# %%
# ── Cell 6: Patch gec_model.py for ALBERT ─────────────────────────────────────
new_gec_model = '''
import logging
import os
from time import time

import torch
from transformers import AutoTokenizer

from gector.seq2labels_model import Seq2Labels
from utils.helpers import PAD, UNK, get_target_sent_by_edits

logger = logging.getLogger(__file__)

MODEL_PATHS = {
    "bert":          "bert-base-cased",
    "distilbert":    "distilbert-base-uncased",
    "albert":        "albert-base-v2",
    "roberta":       "roberta-base",
    "gpt2":          "gpt2",
    "transformerxl": "transfo-xl-wt103",
    "xlnet":         "xlnet-base-cased",
    "tinybert":      "huawei-noah/TinyBERT_General_4L_312D",
    "mobilebert":    "google/mobilebert-uncased",
}


class SimpleVocab:
    def __init__(self, vocab_path):
        self.token2idx = {}
        self.idx2token = {}
        labels_file = os.path.join(vocab_path, "labels.txt")
        with open(labels_file, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                token = line.strip()
                self.token2idx[token] = idx
                self.idx2token[idx] = token

    def get_token_index(self, token, namespace=None):
        return self.token2idx.get(token, 0)

    def get_token_from_index(self, idx, namespace=None):
        return self.idx2token.get(idx, UNK)

    def __len__(self):
        return len(self.token2idx)


class GecBERTModel(object):
    def __init__(self, vocab_path=None, model_paths=None,
                 weigths=None,
                 max_len=50,
                 min_len=3,
                 lowercase_tokens=False,
                 log=False,
                 iterations=5,
                 min_probability=0.0,
                 model_name="albert",
                 special_tokens_fix=0,
                 is_ensemble=False,
                 min_error_probability=0.0,
                 confidence=0.0,
                 resolve_cycles=False):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.max_len = max_len
        self.min_len = min_len
        self.lowercase_tokens = lowercase_tokens
        self.min_probability = min_probability
        self.min_error_probability = min_error_probability
        self.log = log
        self.iterations = iterations
        self.confidence = confidence
        self.model_weights = list(map(float, weigths)) if weigths else [1] * len(model_paths)

        self.vocab = SimpleVocab(vocab_path)
        num_labels = len(self.vocab)

        weights_name = MODEL_PATHS.get(model_name, model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(weights_name)

        self.models = []
        for model_path in model_paths:
            model = Seq2Labels(
                encoder_name=weights_name,
                num_labels_classes=num_labels,
                num_detect_classes=4,
                confidence=confidence,
                special_tokens_fix=0,
                tune_bert=False,
            ).to(self.device)
            state = torch.load(model_path, map_location=self.device)
            model.load_state_dict(state)
            model.eval()
            self.models.append(model)

        print(f"✅ Loaded {len(self.models)} model(s) on {self.device}")

    def preprocess(self, token_batch):
        seq_lens = [len(s) for s in token_batch if s]
        if not seq_lens:
            return None

        all_input_ids, all_attention_masks, all_offsets = [], [], []

        for sequence in token_batch:
            tokens = sequence[:self.max_len - 1]
            words  = ["$START"] + tokens

            input_ids = []
            offsets   = []
            for word in words:
                word_ids = self.tokenizer.encode(word, add_special_tokens=False)
                if not word_ids:
                    word_ids = [self.tokenizer.unk_token_id]
                offsets.append(len(input_ids))
                input_ids.extend(word_ids)

            cls_id    = self.tokenizer.cls_token_id
            sep_id    = self.tokenizer.sep_token_id
            input_ids = [cls_id] + input_ids + [sep_id]
            offsets   = [o + 1 for o in offsets]

            all_input_ids.append(input_ids)
            all_offsets.append(offsets)

        max_seq_len  = max(len(ids) for ids in all_input_ids)
        max_word_len = max(len(off) for off in all_offsets)
        pad_id = self.tokenizer.pad_token_id or 0

        padded_ids, attn_masks, padded_offsets = [], [], []
        for ids, offsets in zip(all_input_ids, all_offsets):
            pad_len = max_seq_len - len(ids)
            padded_ids.append(ids + [pad_id] * pad_len)
            attn_masks.append([1] * len(ids) + [0] * pad_len)
            off_pad = max_word_len - len(offsets)
            padded_offsets.append(offsets + [0] * off_pad)

        return {
            "input_ids":      torch.tensor(padded_ids,     dtype=torch.long).to(self.device),
            "attention_mask": torch.tensor(attn_masks,     dtype=torch.long).to(self.device),
            "offsets":        torch.tensor(padded_offsets, dtype=torch.long).to(self.device),
        }

    def predict(self, batch):
        t0 = time()
        predictions = []
        for model in self.models:
            with torch.no_grad():
                output = model.forward(
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    offsets=batch["offsets"],
                )
            predictions.append(output)
        probs, idx, error_probs = self._convert(predictions)
        if self.log:
            print(f"Inference time {time() - t0:.2f}s")
        return probs, idx, error_probs

    def _convert(self, data):
        all_class_probs = torch.zeros_like(data[0]["class_probabilities_labels"])
        error_probs     = torch.zeros_like(data[0]["max_error_probability"])
        for output, weight in zip(data, self.model_weights):
            all_class_probs += weight * output["class_probabilities_labels"] / sum(self.model_weights)
            error_probs     += weight * output["max_error_probability"]      / sum(self.model_weights)
        max_vals = torch.max(all_class_probs, dim=-1)
        return max_vals[0].tolist(), max_vals[1].tolist(), error_probs.tolist()

    def get_token_action(self, token, index, prob, sugg_token):
        if prob < self.min_probability or sugg_token in [UNK, PAD, "$KEEP"]:
            return None
        if sugg_token.startswith("$REPLACE_") or sugg_token.startswith("$TRANSFORM_") or sugg_token == "$DELETE":
            start_pos, end_pos = index, index + 1
        elif sugg_token.startswith("$APPEND_") or sugg_token.startswith("$MERGE_"):
            start_pos = end_pos = index + 1
        else:
            return None
        sugg_token_clear = "" if sugg_token == "$DELETE" else (
            sugg_token if sugg_token.startswith("$TRANSFORM_") or sugg_token.startswith("$MERGE_")
            else sugg_token[sugg_token.index("_") + 1:]
        )
        return start_pos - 1, end_pos - 1, sugg_token_clear, prob

    def postprocess_batch(self, batch, all_probabilities, all_idxs, error_probs):
        all_results = []
        noop_index = self.vocab.get_token_index("$KEEP", "labels")
        for tokens, probabilities, idxs, error_prob in zip(
                batch, all_probabilities, all_idxs, error_probs):
            length = min(len(tokens), self.max_len)
            if max(idxs) == 0 or error_prob < self.min_error_probability:
                all_results.append(tokens)
                continue
            edits = []
            for i in range(length):
                token = tokens[i - 1]
                if idxs[i] == noop_index:
                    continue
                sugg_token = self.vocab.get_token_from_index(idxs[i], "labels")
                action = self.get_token_action(token, i, probabilities[i], sugg_token)
                if action:
                    edits.append(action)
            all_results.append(get_target_sent_by_edits(tokens, edits))
        return all_results

    def update_final_batch(self, final_batch, pred_ids, pred_batch, prev_preds_dict):
        new_pred_ids  = []
        total_updated = 0
        for i, orig_id in enumerate(pred_ids):
            orig       = final_batch[orig_id]
            pred       = pred_batch[i]
            prev_preds = prev_preds_dict[orig_id]
            if orig != pred and pred not in prev_preds:
                final_batch[orig_id] = pred
                new_pred_ids.append(orig_id)
                prev_preds_dict[orig_id].append(pred)
                total_updated += 1
            elif orig != pred and pred in prev_preds:
                final_batch[orig_id] = pred
                total_updated += 1
        return final_batch, new_pred_ids, total_updated

    def handle_batch(self, full_batch):
        final_batch     = full_batch[:]
        batch_size      = len(full_batch)
        prev_preds_dict = {i: [final_batch[i]] for i in range(batch_size)}
        short_ids       = [i for i in range(batch_size) if len(full_batch[i]) < self.min_len]
        pred_ids        = [i for i in range(batch_size) if i not in short_ids]
        total_updates   = 0

        for n_iter in range(self.iterations):
            orig_batch = [final_batch[i] for i in pred_ids]
            sequences  = self.preprocess(orig_batch)
            if not sequences:
                break
            probabilities, idxs, error_probs = self.predict(sequences)
            pred_batch = self.postprocess_batch(orig_batch, probabilities, idxs, error_probs)
            if self.log:
                print(f"Iteration {n_iter + 1}: {round(100*len(pred_ids)/batch_size, 1)}% of sentences active")
            final_batch, pred_ids, cnt = self.update_final_batch(
                final_batch, pred_ids, pred_batch, prev_preds_dict)
            total_updates += cnt
            if not pred_ids:
                break

        return final_batch, total_updates
'''

import os
with open(f"{WORK_DIR}/gector/gec_model.py", "w") as f:
    f.write(new_gec_model)
print("✅ gec_model.py patched for ALBERT!")
# Out:
# ✅ gec_model.py patched for ALBERT!

# %%
# ── Cell 7: Restore Stage 3 checkpoint from Drive ────────────────────────────────
import shutil, os

os.makedirs(STAGE3_DIR, exist_ok=True)

print("Restoring Stage 3 best model from Drive...")
src = os.path.join(STAGE3_CKPT, "model_best.th")
dst = os.path.join(STAGE3_DIR, "model_best.th")
if os.path.exists(src):
    shutil.copy(src, dst)
    size = os.path.getsize(dst) / 1e6
    print(f"  ✅ model_best.th ({size:.1f} MB)")
else:
    print(f"  ❌ Not found: {src}")

print("\n✅ Model ready for inference!")
# Out:
# Restoring Stage 3 best model from Drive...
#   ✅ model_best.th (62.1 MB)
#
# ✅ Model ready for inference!

# %%
# ── Cell 8: BEA-2019 Test Set Inference + submission.zip ──────────────────────
import shutil, os, subprocess, sys, zipfile, time, torch

# ── Paths ──
TEST_ORIG   = f"{TEST_DIR}/ABCN.test.bea19.orig"
PRED_OUTPUT = "/content/predictions.txt"

with open(TEST_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Test input ready ({count} sentences) → {TEST_ORIG}")

# ── GPU RAM before inference ──────────────────────────────────────────────────
print()
print("=" * 50)
print("GPU RAM BEFORE TEST INFERENCE")
print("=" * 50)
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats(0)
    mem_before = torch.cuda.memory_allocated(0) / 1e6
    print(f"  Allocated : {mem_before:.1f} MB")
    print(f"  Reserved  : {torch.cuda.memory_reserved(0) / 1e6:.1f} MB")

# ── Model parameters ──────────────────────────────────────────────────────────
print()
print("=" * 50)
print("MODEL PARAMETERS")
print("=" * 50)
try:
    _state = torch.load(f"{STAGE3_DIR}/model_best.th", map_location="cpu")
    _params = sum(p.numel() for p in _state.values() if hasattr(p, "numel"))
    print(f"  Total parameters : {_params:,}  ({_params/1e6:.2f} M)")
    del _state
except Exception as e:
    print(f"  Could not load state dict: {e}")

# ── Run inference ──
os.chdir(WORK_DIR)
predict_cmd = [
    "python", "predict.py",
    "--model_path",            f"{STAGE3_DIR}/model_best.th",
    "--vocab_path",            VOCAB_PATH,
    "--input_file",            TEST_ORIG,
    "--output_file",           PRED_OUTPUT,
    "--transformer_model",     "albert",
    "--iteration_count",       "5",
    "--min_error_probability", "0.1",
    "--min_probability",       "0.0",
    "--additional_confidence", "0.0",
    "--special_tokens_fix",    "0",
]

print()
print("Running inference on BEA-2019 test set (ALBERT)...")
t_start = time.time()
process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="", flush=True)
process.wait()
t_end = time.time()

with open(PRED_OUTPUT) as f:
    pred_count = sum(1 for _ in f)
print(f"\n✅ Predictions written ({pred_count} lines) → {PRED_OUTPUT}")

# ── Inference time + GPU RAM after ───────────────────────────────────────────
elapsed  = t_end - t_start
per_sent = elapsed / count if count > 0 else 0

print()
print("=" * 50)
print("INFERENCE STATS — TEST SET")
print("=" * 50)
print(f"  Sentences        : {count}")
print(f"  Total time       : {elapsed:.1f} s  ({elapsed/60:.2f} min)")
print(f"  Time / sentence  : {per_sent*1000:.1f} ms")
if torch.cuda.is_available():
    mem_after = torch.cuda.memory_allocated(0) / 1e6
    mem_peak  = torch.cuda.max_memory_allocated(0) / 1e6
    print(f"  GPU RAM before   : {mem_before:.1f} MB")
    print(f"  GPU RAM after    : {mem_after:.1f} MB")
    print(f"  GPU RAM peak     : {mem_peak:.1f} MB")
    print(f"  GPU RAM delta    : {mem_after - mem_before:+.1f} MB")

# ── nvidia-smi snapshot ───────────────────────────────────────────────────────
print()
print("=" * 50)
print("GPU USAGE (nvidia-smi)")
print("=" * 50)
_smi = subprocess.run(
    ["nvidia-smi",
     "--query-gpu=index,name,temperature.gpu,utilization.gpu,utilization.memory,memory.used,memory.free,memory.total",
     "--format=csv,noheader,nounits"],
    capture_output=True, text=True
)
if _smi.returncode == 0:
    for line in _smi.stdout.strip().split("\n"):
        idx, name, temp, gpu_util, mem_util, mem_used, mem_free, mem_total = [x.strip() for x in line.split(",")]
        print(f"  GPU {idx}        : {name}")
        print(f"  Temperature  : {temp} °C")
        print(f"  GPU Util     : {gpu_util} %")
        print(f"  Memory Util  : {mem_util} %")
        print(f"  Memory Used  : {mem_used} MB / {mem_total} MB")
        print(f"  Memory Free  : {mem_free} MB")
else:
    print("  nvidia-smi not available:", _smi.stderr)

print()
print("=" * 50)
print("TORCH CUDA MEMORY")
print("=" * 50)
print(f"  Allocated : {round(torch.cuda.memory_allocated(0) / 1e6, 1)} MB")
print(f"  Reserved  : {round(torch.cuda.memory_reserved(0) / 1e6, 1)} MB")

# ── Package submission.zip ──
zip_path = "/content/submission.zip"
with zipfile.ZipFile(zip_path, "w") as z:
    z.write(PRED_OUTPUT, "predictions.txt")
size = os.path.getsize(zip_path) / 1024
print(f"\n✅ submission.zip ready ({size:.1f} KB) → {zip_path}")
print("Download submission.zip and upload to CodaBench!")

# ── Also save to Drive ──
drive_pred = os.path.join(EVAL_OUT, "test_predictions.txt")
drive_zip  = os.path.join(EVAL_OUT, "submission.zip")
shutil.copy(PRED_OUTPUT, drive_pred)
shutil.copy(zip_path,    drive_zip)
print(f"✅ Also saved to Drive: {drive_zip}")
print(f"   → {EVAL_OUT}")
# Out:
# ✅ Test input ready (4477 sentences) → /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.test.bea19.orig
#
# ==================================================
# GPU RAM BEFORE TEST INFERENCE
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
#
# ==================================================
# MODEL PARAMETERS
# ==================================================
#   Total parameters : 15,533,198  (15.53 M)
#
# Running inference on BEA-2019 test set (ALBERT)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/25 [00:00<?, ?it/s]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 15252.01it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 5949.37it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 4779.83it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 3896.24it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 3317.40it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 2905.31it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 2408.44it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 2236.07it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 1974.91it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 1880.52it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 1915.64it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 1830.24it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 1923.74it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 1853.19it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 1757.14it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 1713.01it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 1838.08it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 1801.76it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 1861.32it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 1817.45it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 1862.48it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 1827.87it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 1920.54it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 1881.77it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1901.85it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1871.81it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1903.29it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1870.73it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1429.26it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1408.05it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1452.38it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1438.47it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 1499.19it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 1485.79it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1535.81it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1521.02it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1578.62it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1564.49it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1619.39it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1604.49it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1651.95it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1634.72it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1684.00it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1668.56it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1719.41it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1706.45it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1755.40it/s, Materializing param=pooler.bias]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1743.90it/s, Materializing param=pooler.bias]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1798.28it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1785.05it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1760.95it/s, Materializing param=pooler.weight]
# AlbertModel LOAD REPORT from: albert-base-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# predictions.LayerNorm.weight | UNEXPECTED |  |
# predictions.bias             | UNEXPECTED |  |
# predictions.decoder.bias     | UNEXPECTED |  |
# predictions.dense.weight     | UNEXPECTED |  |
# predictions.LayerNorm.bias   | UNEXPECTED |  |
# predictions.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 2456
#
# ✅ Predictions written (4477 lines) → /content/predictions.txt
#
# ==================================================
# INFERENCE STATS — TEST SET
# ==================================================
#   Sentences        : 4477
#   Total time       : 51.7 s  (0.86 min)
#   Time / sentence  : 11.5 ms
#   GPU RAM before   : 0.0 MB
#   GPU RAM after    : 0.0 MB
#   GPU RAM peak     : 0.0 MB
#   GPU RAM delta    : +0.0 MB
#
# ==================================================
# GPU USAGE (nvidia-smi)
# ==================================================
#   GPU 0        : Tesla T4
#   Temperature  : 54 °C
#   GPU Util     : 0 %
#   Memory Util  : 0 %
#   Memory Used  : 3 MB / 15360 MB
#   Memory Free  : 14910 MB
#
# ==================================================
# TORCH CUDA MEMORY
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
#
# ✅ submission.zip ready (428.5 KB) → /content/submission.zip
# Download submission.zip and upload to CodaBench!
# ✅ Also saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/submission.zip
#    → /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert

# %%
# ── Cell 9: Extract dev orig sentences from Gold M2 ──────────────────────────
import os

print("Extracting dev orig from gold m2...")
with open(GOLD_M2, encoding='utf-8') as f_in, \
     open(DEV_ORIG, 'w', encoding='utf-8') as f_out:
    for line in f_in:
        if line.startswith("S "):
            f_out.write(line[2:])

with open(DEV_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Extracted {count} source sentences → {DEV_ORIG}")
# Out:
# Extracting dev orig from gold m2...
# ✅ Extracted 4384 source sentences → /content/ABCN.dev.orig.txt

# %%
# ── Cell 10: Run inference on dev set ─────────────────────────────────────────
import subprocess, os, sys, time, torch

os.chdir(WORK_DIR)

predict_cmd = [
    "python", "predict.py",
    "--model_path",           f"{STAGE3_DIR}/model_best.th",
    "--vocab_path",           VOCAB_PATH,
    "--input_file",           DEV_ORIG,
    "--output_file",          DEV_PRED,
    "--transformer_model",    "albert",
    "--iteration_count",      "5",
    "--min_error_probability","0.1",
    "--min_probability",      "0.0",
    "--additional_confidence","0.0",
    "--special_tokens_fix",   "0",
    "--lowercase_tokens",     "1",
]

# ── GPU RAM before inference ──────────────────────────────────────────────────
print("=" * 50)
print("GPU RAM BEFORE DEV INFERENCE")
print("=" * 50)
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats(0)
    mem_before_dev = torch.cuda.memory_allocated(0) / 1e6
    print(f"  Allocated : {mem_before_dev:.1f} MB")
    print(f"  Reserved  : {torch.cuda.memory_reserved(0) / 1e6:.1f} MB")
print()

# ── Model parameters ──────────────────────────────────────────────────────────
print("=" * 50)
print("MODEL PARAMETERS")
print("=" * 50)
try:
    _state = torch.load(f"{STAGE3_DIR}/model_best.th", map_location="cpu")
    _params = sum(p.numel() for p in _state.values() if hasattr(p, "numel"))
    _size   = sum(p.numel() * p.element_size() for p in _state.values() if hasattr(p, "numel"))
    print(f"  Total parameters : {_params:,}  ({_params/1e6:.2f} M)")
    print(f"  Model size       : {_size / 1e6:.1f} MB (float32)")
    del _state
except Exception as e:
    print(f"  ❌ Could not load state dict: {e}")
    import traceback; traceback.print_exc()
print()

print("Running inference on dev set (ALBERT)...")
print(f"  Input : {DEV_ORIG}")
print(f"  Output: {DEV_PRED}")
print()

t_start = time.time()
process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="", flush=True)
process.wait()
t_end = time.time()

print("\n✅ Inference done!")

# ── Count sentences ───────────────────────────────────────────────────────────
with open(DEV_ORIG) as f:
    dev_count = sum(1 for _ in f)

elapsed_dev  = t_end - t_start
per_sent_dev = elapsed_dev / dev_count if dev_count > 0 else 0

# ── Inference time + GPU RAM after ───────────────────────────────────────────
print()
print("=" * 50)
print("INFERENCE STATS — DEV SET")
print("=" * 50)
print(f"  Sentences        : {dev_count}")
print(f"  Total time       : {elapsed_dev:.1f} s  ({elapsed_dev/60:.2f} min)")
print(f"  Time / sentence  : {per_sent_dev*1000:.1f} ms")
if torch.cuda.is_available():
    mem_after_dev = torch.cuda.memory_allocated(0) / 1e6
    mem_peak_dev  = torch.cuda.max_memory_allocated(0) / 1e6
    print(f"  GPU RAM before   : {mem_before_dev:.1f} MB")
    print(f"  GPU RAM after    : {mem_after_dev:.1f} MB")
    print(f"  GPU RAM peak     : {mem_peak_dev:.1f} MB")
    print(f"  GPU RAM delta    : {mem_after_dev - mem_before_dev:+.1f} MB")

# ── nvidia-smi snapshot ───────────────────────────────────────────────────────
print()
print("=" * 50)
print("GPU USAGE (nvidia-smi)")
print("=" * 50)
_smi = subprocess.run(
    ["nvidia-smi",
     "--query-gpu=index,name,temperature.gpu,utilization.gpu,utilization.memory,memory.used,memory.free,memory.total",
     "--format=csv,noheader,nounits"],
    capture_output=True, text=True
)
if _smi.returncode == 0:
    for line in _smi.stdout.strip().split("\n"):
        idx, name, temp, gpu_util, mem_util, mem_used, mem_free, mem_total = [x.strip() for x in line.split(",")]
        print(f"  GPU {idx}        : {name}")
        print(f"  Temperature  : {temp} °C")
        print(f"  GPU Util     : {gpu_util} %")
        print(f"  Memory Util  : {mem_util} %")
        print(f"  Memory Used  : {mem_used} MB / {mem_total} MB")
        print(f"  Memory Free  : {mem_free} MB")
else:
    print("  nvidia-smi not available:", _smi.stderr)

print()
print("=" * 50)
print("TORCH CUDA MEMORY")
print("=" * 50)
print(f"  Allocated : {round(torch.cuda.memory_allocated(0) / 1e6, 1)} MB")
print(f"  Reserved  : {round(torch.cuda.memory_reserved(0) / 1e6, 1)} MB")

# ── Save dev predictions to Drive ──
import shutil
shutil.copy(DEV_PRED, os.path.join(EVAL_OUT, "dev_predictions.txt"))
print(f"\n✅ dev_predictions.txt saved to Drive: {EVAL_OUT}")
# Out:
# ==================================================
# GPU RAM BEFORE DEV INFERENCE
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
#
# ==================================================
# MODEL PARAMETERS
# ==================================================
#   Total parameters : 15,533,198  (15.53 M)
#   Model size       : 62.1 MB (float32)
#
# Running inference on dev set (ALBERT)...
#   Input : /content/ABCN.dev.orig.txt
#   Output: /content/dev_predictions.txt
#
#
# Loading weights:   0%|          | 0/25 [00:00<?, ?it/s]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 18477.11it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   4%|▍         | 1/25 [00:00<00:00, 5398.07it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 5226.55it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   8%|▊         | 2/25 [00:00<00:00, 4196.40it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 4404.24it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  12%|█▏        | 3/25 [00:00<00:00, 3986.98it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 4254.94it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  16%|█▌        | 4/25 [00:00<00:00, 3829.54it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 3938.31it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  20%|██        | 5/25 [00:00<00:00, 2836.29it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 2786.30it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  24%|██▍       | 6/25 [00:00<00:00, 2627.19it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 1678.11it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  28%|██▊       | 7/25 [00:00<00:00, 1627.95it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 1451.57it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  32%|███▏      | 8/25 [00:00<00:00, 1406.72it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 1498.14it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  36%|███▌      | 9/25 [00:00<00:00, 1465.40it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 1558.53it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  40%|████      | 10/25 [00:00<00:00, 1534.80it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 1629.89it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  44%|████▍     | 11/25 [00:00<00:00, 1602.44it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 1688.81it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  48%|████▊     | 12/25 [00:00<00:00, 1662.81it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1751.44it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  52%|█████▏    | 13/25 [00:00<00:00, 1726.49it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1707.18it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  56%|█████▌    | 14/25 [00:00<00:00, 1683.64it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1752.35it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  60%|██████    | 15/25 [00:00<00:00, 1726.62it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1801.29it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  64%|██████▍   | 16/25 [00:00<00:00, 1781.68it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.bias]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 1685.97it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  68%|██████▊   | 17/25 [00:00<00:00, 1660.49it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn.weight]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1616.51it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  72%|███████▏  | 18/25 [00:00<00:00, 1598.07it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1586.92it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  76%|███████▌  | 19/25 [00:00<00:00, 1571.58it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1615.87it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  80%|████████  | 20/25 [00:00<00:00, 1602.19it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1657.17it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  84%|████████▍ | 21/25 [00:00<00:00, 1644.18it/s, Materializing param=encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1693.64it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  88%|████████▊ | 22/25 [00:00<00:00, 1679.16it/s, Materializing param=encoder.embedding_hidden_mapping_in.bias]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1725.96it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  92%|█████████▏| 23/25 [00:00<00:00, 1711.66it/s, Materializing param=encoder.embedding_hidden_mapping_in.weight]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1760.71it/s, Materializing param=pooler.bias]
# Loading weights:  96%|█████████▌| 24/25 [00:00<00:00, 1747.38it/s, Materializing param=pooler.bias]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1797.14it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1783.35it/s, Materializing param=pooler.weight]
# Loading weights: 100%|██████████| 25/25 [00:00<00:00, 1754.70it/s, Materializing param=pooler.weight]
# AlbertModel LOAD REPORT from: albert-base-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# predictions.LayerNorm.weight | UNEXPECTED |  |
# predictions.dense.bias       | UNEXPECTED |  |
# predictions.dense.weight     | UNEXPECTED |  |
# predictions.decoder.bias     | UNEXPECTED |  |
# predictions.bias             | UNEXPECTED |  |
# predictions.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 2511
#
# ✅ Inference done!
#
# ==================================================
# INFERENCE STATS — DEV SET
# ==================================================
#   Sentences        : 4384
#   Total time       : 39.2 s  (0.65 min)
#   Time / sentence  : 8.9 ms
#   GPU RAM before   : 0.0 MB
#   GPU RAM after    : 0.0 MB
#   GPU RAM peak     : 0.0 MB
#   GPU RAM delta    : +0.0 MB
#
# ==================================================
# GPU USAGE (nvidia-smi)
# ==================================================
#   GPU 0        : Tesla T4
#   Temperature  : 62 °C
#   GPU Util     : 0 %
#   Memory Util  : 0 %
#   Memory Used  : 3 MB / 15360 MB
#   Memory Free  : 14910 MB
#
# ==================================================
# TORCH CUDA MEMORY
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
#
# ✅ dev_predictions.txt saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert

# %%
import os
os.system("pip install errant -q")
os.system("python -m spacy download en -q")
print("✅ ERRANT installed!")
# Out:
# ✅ ERRANT installed!

# %%
# ── Cell 11: ERRANT annotation + scoring ──────────────────────────────────────
import os, shutil

print("Running ERRANT annotation on dev predictions...")
ret = os.system(f"errant_parallel -orig {DEV_ORIG} -cor {DEV_PRED} -out {DEV_HYP_M2}")
print(f"errant_parallel exit code: {ret}")

if os.path.exists(DEV_HYP_M2):
    print("✅ dev_hyp.m2 created!")
else:
    print("❌ dev_hyp.m2 not created — check exit code above")
    # Debug: check if input files exist and have content
    for label, path in [("DEV_ORIG", DEV_ORIG), ("DEV_PRED", DEV_PRED)]:
        if os.path.exists(path):
            with open(path) as f:
                lines = sum(1 for _ in f)
            print(f"  {label}: {lines} lines → {path}")
        else:
            print(f"  ❌ {label} missing: {path}")

if not os.path.exists(DEV_HYP_M2):
    raise FileNotFoundError("dev_hyp.m2 not created — fix errant_parallel error above first")

with open(DEV_HYP_M2) as f:
    hyp_count = sum(1 for line in f if line.startswith("S "))
with open(GOLD_M2) as f:
    gold_count = sum(1 for line in f if line.startswith("S "))

print(f"hyp sentences:  {hyp_count}")
print(f"gold sentences: {gold_count}")

if hyp_count != gold_count:
    print("❌ Sentence count mismatch!")
else:
    print("\n========================================")
    print("ERRANT Scores on BEA-2019 Dev Set:")
    print("(Precision / Recall / F0.5)")
    print("========================================")
    result = os.popen(f"errant_compare -hyp {DEV_HYP_M2} -ref {GOLD_M2} 2>&1").read()
    print(result)

# ── Save to Drive ──
shutil.copy(DEV_HYP_M2, os.path.join(EVAL_OUT, "dev_hyp.m2"))
print(f"✅ dev_hyp.m2 saved to Drive: {EVAL_OUT}")
# Out:
# Running ERRANT annotation on dev predictions...
# errant_parallel exit code: 0
# ✅ dev_hyp.m2 created!
# hyp sentences:  4384
# gold sentences: 4384
#
# ========================================
# ERRANT Scores on BEA-2019 Dev Set:
# (Precision / Recall / F0.5)
# ========================================
#
# =========== Span-Based Correction ============
# TP	FP	FN	Prec	Rec	F0.5
# 1890	1871	5571	0.5025	0.2533	0.4199
# ==============================================
#
#
# ✅ dev_hyp.m2 saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert

# %%
# ── Cell 12: Zip final model for download / archiving ─────────────────────────
import zipfile, os

zip_path = "/content/stage3_albert_final.zip"

files_to_zip = [
    (f"{STAGE3_DIR}/model_best.th",       "model_best.th"),
    (f"{WORK_DIR}/gector/gec_model.py",   "gec_model.py"),
    (f"{WORK_DIR}/predict.py",            "predict.py"),
]

with zipfile.ZipFile(zip_path, "w") as z:
    for src, arcname in files_to_zip:
        if os.path.exists(src):
            z.write(src, arcname)
            print(f"✅ Added {arcname}")
        else:
            print(f"❌ MISSING: {src}")

    # Add output_vocabulary folder
    for root, dirs, files in os.walk(VOCAB_PATH):
        for file in files:
            full_path = os.path.join(root, file)
            arcname = os.path.join("output_vocabulary", os.path.relpath(full_path, VOCAB_PATH))
            z.write(full_path, arcname)
    print("✅ Added output_vocabulary/")

size = os.path.getsize(zip_path) / 1e6
print(f"\n✅ Done! stage3_albert_final.zip ({size:.1f} MB) → {zip_path}")

# Also copy to Drive
import shutil
drive_zip = os.path.join(EVAL_OUT, "stage3_albert_final.zip")
shutil.copy(zip_path, drive_zip)
print(f"✅ Also saved to Drive: {drive_zip}")
# Out:
# ✅ Added model_best.th
# ✅ Added gec_model.py
# ✅ Added predict.py
# ✅ Added output_vocabulary/
#
# ✅ Done! stage3_albert_final.zip (62.2 MB) → /content/stage3_albert_final.zip
# ✅ Also saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/albert/stage3_albert_final.zip

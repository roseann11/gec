# %% [markdown]
# # STAGE 1 DEV RESULT

# %%
# ── Cell 1: Mount Google Drive ────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Cell 2: Verify GPU ──────────────────────────────────────────────────────
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
# ── Cell 3: Paths — UPDATE DRIVE_ROOT to match your Shared Drive ──────────────
import os

# ── EDIT THESE ──
DRIVE_ROOT   = "/content/drive/Shareddrives/gec_thesis/gec_thesis"
DATASETS_DIR = f"{DRIVE_ROOT}/gec_gector_datasets_new"
TEST_DIR     = f"{DRIVE_ROOT}/gec_test_data"
CODE_DIR     = f"{DRIVE_ROOT}/gector_code_mobilebert"
STAGE1_CKPT  = f"{DRIVE_ROOT}/models/stage1/mobilebert"       # folder with model_best.th
EVAL_OUT     = f"{DRIVE_ROOT}/models/eval/mobilebert/stage1"  # evaluation outputs go here

# ── Local working dirs ──
WORK_DIR   = "/content/gector"
STAGE1_DIR = "/content/models/stage1/mobilebert"

for d in [WORK_DIR, STAGE1_DIR, EVAL_OUT]:
    os.makedirs(d, exist_ok=True)

# ── Dataset paths ──
WI_TRAIN   = f"{DATASETS_DIR}/wi_train_gector.txt"
WI_DEV     = f"{DATASETS_DIR}/wi_dev_gector.txt"
VOCAB_PATH = f"{WORK_DIR}/data/output_vocabulary"

# ── Eval paths ──
GOLD_M2    = f"{TEST_DIR}/ABCN.dev.gold.bea19.m2"
DEV_ORIG   = "/content/ABCN.dev.orig.txt"
DEV_PRED   = "/content/dev_predictions.txt"
DEV_HYP_M2 = "/content/dev_hyp.m2"

print("✅ Paths defined!")
print(f"   DRIVE_ROOT  : {DRIVE_ROOT}")
print(f"   CODE_DIR    : {CODE_DIR}")
print(f"   STAGE1_CKPT : {STAGE1_CKPT}")
print(f"   EVAL_OUT    : {EVAL_OUT}")
# Out:
# ✅ Paths defined!
#    DRIVE_ROOT  : /content/drive/Shareddrives/gec_thesis/gec_thesis
#    CODE_DIR    : /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_mobilebert
#    STAGE1_CKPT : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage1/mobilebert
#    EVAL_OUT    : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage1

# %%
# ── Cell 4: Verify all input files ────────────────────────────────────────────
import os

checks = [
    ("W&I Train",                      WI_TRAIN),
    ("W&I Dev",                        WI_DEV),
    ("Gold M2",                        GOLD_M2),
    ("Stage1 model_best.th",           os.path.join(STAGE1_CKPT, "model_best.th")),
    ("Code dir",                       CODE_DIR),
]

all_ok = True
for name, path in checks:
    exists = os.path.exists(path)
    print(f"  {'✅' if exists else '❌'} {name}: {path}")
    if not exists:
        all_ok = False

print()
print("✅ All files found — ready to proceed!" if all_ok else "❌ Fix missing files above before continuing.")
# Out:
#   ✅ W&I Train: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_train_gector.txt
#   ✅ W&I Dev: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_dev_gector.txt
#   ✅ Gold M2: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.dev.gold.bea19.m2
#   ✅ Stage1 model_best.th: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage1/mobilebert/model_best.th
#   ✅ Code dir: /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_mobilebert
#
# ✅ All files found — ready to proceed!

# %%
# ── Cell 5: Copy gector_code_mobilebert to local working dir ──────────────────────
import shutil, os

if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)
shutil.copytree(CODE_DIR, WORK_DIR)
print("✅ Code copied to", WORK_DIR)

for root, dirs, files in os.walk(WORK_DIR):
    for f in files:
        print(os.path.join(root, f).replace(WORK_DIR, ""))
# Out:
# ✅ Code copied to /content/gector
# /README_MOBILEBERT.md
# /requirements.txt
# /predict.py
# /train.py
# /resume_training.py
# /utils/prepare_clc_fce_data.py
# /utils/preprocess_data.py
# /utils/helpers.py
# /data/verb-form-vocab.txt
# /data/output_vocabulary/d_tags.txt
# /data/output_vocabulary/labels.txt
# /data/output_vocabulary/non_padded_namespaces.txt
# /gector/gec_model.py
# /gector/seq2labels_model.py
# /gector/trainer.py
# /gector/datareader.py

# %%
# ── Cell 6: Patch gec_model.py for MOBILBERT ─────────────────────────────────────
new_gec_model = '''
import logging
import os
from time import time

import torch
from transformers import AutoTokenizer

from gector.seq2labels_model import Seq2Labels
from utils.helpers import PAD, UNK, get_target_sent_by_edits

logger = logging.getLogger(__file__)

MODEL_PATHS = {
    "bert":          "bert-base-cased",
    "distilbert":    "distilbert-base-uncased",
    "albert":        "albert-base-v2",
    "roberta":       "roberta-base",
    "gpt2":          "gpt2",
    "transformerxl": "transfo-xl-wt103",
    "xlnet":         "xlnet-base-cased",
    "tinybert":      "huawei-noah/TinyBERT_General_4L_312D",
    "mobilebert":    "google/mobilebert-uncased",
}


class SimpleVocab:
    def __init__(self, vocab_path):
        self.token2idx = {}
        self.idx2token = {}
        labels_file = os.path.join(vocab_path, "labels.txt")
        with open(labels_file, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                token = line.strip()
                self.token2idx[token] = idx
                self.idx2token[idx] = token

    def get_token_index(self, token, namespace=None):
        return self.token2idx.get(token, 0)

    def get_token_from_index(self, idx, namespace=None):
        return self.idx2token.get(idx, UNK)

    def __len__(self):
        return len(self.token2idx)


class GecBERTModel(object):
    def __init__(self, vocab_path=None, model_paths=None,
                 weigths=None,
                 max_len=50,
                 min_len=3,
                 lowercase_tokens=False,
                 log=False,
                 iterations=5,
                 min_probability=0.0,
                 model_name="mobilbert",
                 special_tokens_fix=0,
                 is_ensemble=False,
                 min_error_probability=0.0,
                 confidence=0.0,
                 resolve_cycles=False):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.max_len = max_len
        self.min_len = min_len
        self.lowercase_tokens = lowercase_tokens
        self.min_probability = min_probability
        self.min_error_probability = min_error_probability
        self.log = log
        self.iterations = iterations
        self.confidence = confidence
        self.model_weights = list(map(float, weigths)) if weigths else [1] * len(model_paths)

        self.vocab = SimpleVocab(vocab_path)
        num_labels = len(self.vocab)

        weights_name = MODEL_PATHS.get(model_name, model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(weights_name)

        self.models = []
        for model_path in model_paths:
            model = Seq2Labels(
                encoder_name=weights_name,
                num_labels_classes=num_labels,
                num_detect_classes=4,
                confidence=confidence,
                special_tokens_fix=0,
                tune_bert=False,
            ).to(self.device)
            state = torch.load(model_path, map_location=self.device)
            model.load_state_dict(state)
            model.eval()
            self.models.append(model)

        print(f"✅ Loaded {len(self.models)} model(s) on {self.device}")

    def preprocess(self, token_batch):
        seq_lens = [len(s) for s in token_batch if s]
        if not seq_lens:
            return None

        all_input_ids, all_attention_masks, all_offsets = [], [], []

        for sequence in token_batch:
            tokens = sequence[:self.max_len - 1]
            words  = ["$START"] + tokens

            input_ids = []
            offsets   = []
            for word in words:
                word_ids = self.tokenizer.encode(word, add_special_tokens=False)
                if not word_ids:
                    word_ids = [self.tokenizer.unk_token_id]
                offsets.append(len(input_ids))
                input_ids.extend(word_ids)

            cls_id    = self.tokenizer.cls_token_id
            sep_id    = self.tokenizer.sep_token_id
            input_ids = [cls_id] + input_ids + [sep_id]
            offsets   = [o + 1 for o in offsets]

            all_input_ids.append(input_ids)
            all_offsets.append(offsets)

        max_seq_len  = max(len(ids) for ids in all_input_ids)
        max_word_len = max(len(off) for off in all_offsets)
        pad_id = self.tokenizer.pad_token_id or 0

        padded_ids, attn_masks, padded_offsets = [], [], []
        for ids, offsets in zip(all_input_ids, all_offsets):
            pad_len = max_seq_len - len(ids)
            padded_ids.append(ids + [pad_id] * pad_len)
            attn_masks.append([1] * len(ids) + [0] * pad_len)
            off_pad = max_word_len - len(offsets)
            padded_offsets.append(offsets + [0] * off_pad)

        return {
            "input_ids":      torch.tensor(padded_ids,     dtype=torch.long).to(self.device),
            "attention_mask": torch.tensor(attn_masks,     dtype=torch.long).to(self.device),
            "offsets":        torch.tensor(padded_offsets, dtype=torch.long).to(self.device),
        }

    def predict(self, batch):
        t0 = time()
        predictions = []
        for model in self.models:
            with torch.no_grad():
                output = model.forward(
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    offsets=batch["offsets"],
                )
            predictions.append(output)
        probs, idx, error_probs = self._convert(predictions)
        if self.log:
            print(f"Inference time {time() - t0:.2f}s")
        return probs, idx, error_probs

    def _convert(self, data):
        all_class_probs = torch.zeros_like(data[0]["class_probabilities_labels"])
        error_probs     = torch.zeros_like(data[0]["max_error_probability"])
        for output, weight in zip(data, self.model_weights):
            all_class_probs += weight * output["class_probabilities_labels"] / sum(self.model_weights)
            error_probs     += weight * output["max_error_probability"]      / sum(self.model_weights)
        max_vals = torch.max(all_class_probs, dim=-1)
        return max_vals[0].tolist(), max_vals[1].tolist(), error_probs.tolist()

    def get_token_action(self, token, index, prob, sugg_token):
        if prob < self.min_probability or sugg_token in [UNK, PAD, "$KEEP"]:
            return None
        if sugg_token.startswith("$REPLACE_") or sugg_token.startswith("$TRANSFORM_") or sugg_token == "$DELETE":
            start_pos, end_pos = index, index + 1
        elif sugg_token.startswith("$APPEND_") or sugg_token.startswith("$MERGE_"):
            start_pos = end_pos = index + 1
        else:
            return None
        sugg_token_clear = "" if sugg_token == "$DELETE" else (
            sugg_token if sugg_token.startswith("$TRANSFORM_") or sugg_token.startswith("$MERGE_")
            else sugg_token[sugg_token.index("_") + 1:]
        )
        return start_pos - 1, end_pos - 1, sugg_token_clear, prob

    def postprocess_batch(self, batch, all_probabilities, all_idxs, error_probs):
        all_results = []
        noop_index = self.vocab.get_token_index("$KEEP", "labels")
        for tokens, probabilities, idxs, error_prob in zip(
                batch, all_probabilities, all_idxs, error_probs):
            length = min(len(tokens), self.max_len)
            if max(idxs) == 0 or error_prob < self.min_error_probability:
                all_results.append(tokens)
                continue
            edits = []
            for i in range(length):
                token = tokens[i - 1]
                if idxs[i] == noop_index:
                    continue
                sugg_token = self.vocab.get_token_from_index(idxs[i], "labels")
                action = self.get_token_action(token, i, probabilities[i], sugg_token)
                if action:
                    edits.append(action)
            all_results.append(get_target_sent_by_edits(tokens, edits))
        return all_results

    def update_final_batch(self, final_batch, pred_ids, pred_batch, prev_preds_dict):
        new_pred_ids  = []
        total_updated = 0
        for i, orig_id in enumerate(pred_ids):
            orig       = final_batch[orig_id]
            pred       = pred_batch[i]
            prev_preds = prev_preds_dict[orig_id]
            if orig != pred and pred not in prev_preds:
                final_batch[orig_id] = pred
                new_pred_ids.append(orig_id)
                prev_preds_dict[orig_id].append(pred)
                total_updated += 1
            elif orig != pred and pred in prev_preds:
                final_batch[orig_id] = pred
                total_updated += 1
        return final_batch, new_pred_ids, total_updated

    def handle_batch(self, full_batch):
        final_batch     = full_batch[:]
        batch_size      = len(full_batch)
        prev_preds_dict = {i: [final_batch[i]] for i in range(batch_size)}
        short_ids       = [i for i in range(batch_size) if len(full_batch[i]) < self.min_len]
        pred_ids        = [i for i in range(batch_size) if i not in short_ids]
        total_updates   = 0

        for n_iter in range(self.iterations):
            orig_batch = [final_batch[i] for i in pred_ids]
            sequences  = self.preprocess(orig_batch)
            if not sequences:
                break
            probabilities, idxs, error_probs = self.predict(sequences)
            pred_batch = self.postprocess_batch(orig_batch, probabilities, idxs, error_probs)
            if self.log:
                print(f"Iteration {n_iter + 1}: {round(100*len(pred_ids)/batch_size, 1)}% of sentences active")
            final_batch, pred_ids, cnt = self.update_final_batch(
                final_batch, pred_ids, pred_batch, prev_preds_dict)
            total_updates += cnt
            if not pred_ids:
                break

        return final_batch, total_updates
'''

import os
with open(f"{WORK_DIR}/gector/gec_model.py", "w") as f:
    f.write(new_gec_model)
print("✅ gec_model.py patched for MOBILEBERT!")
# Out:
# ✅ gec_model.py patched for MOBILEBERT!

# %%
content = open(f"{WORK_DIR}/predict.py").read()

content = content.replace(
    "choices=['bert', 'gpt2', 'transformerxl', 'xlnet', 'distilbert', 'roberta', 'albert']",
    "choices=['bert', 'gpt2', 'transformerxl', 'xlnet', 'distilbert', 'roberta', 'albert', 'mobilebert']"
)

with open(f"{WORK_DIR}/predict.py", "w") as f:
    f.write(content)

print("✅ MobileBERT added to predict.py!")
# Out:
# ✅ MobileBERT added to predict.py!

# %%
# ── Cell 6: Restore Stage 1 checkpoint from Drive ────────────────────────────────
import shutil, os

os.makedirs(STAGE1_DIR, exist_ok=True)

print("Restoring Stage 1 best model from Drive...")
src = os.path.join(STAGE1_CKPT, "model_best.th")
dst = os.path.join(STAGE1_DIR, "model_best.th")
if os.path.exists(src):
    shutil.copy(src, dst)
    size = os.path.getsize(dst) / 1e6
    print(f"  ✅ model_best.th ({size:.1f} MB)")
else:
    print(f"  ❌ Not found: {src}")

print("\n✅ Model ready for inference!")
# Out:
# Restoring Stage 1 best model from Drive...
#   ✅ model_best.th (109.1 MB)
#
# ✅ Model ready for inference!

# %%
# ── Cell 13: Extract dev orig sentences from Gold M2 ──────────────────────────
import os

print("Extracting dev orig from gold m2...")
with open(GOLD_M2, encoding='utf-8') as f_in, \
     open(DEV_ORIG, 'w', encoding='utf-8') as f_out:
    for line in f_in:
        if line.startswith("S "):
            f_out.write(line[2:])

with open(DEV_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Extracted {count} source sentences → {DEV_ORIG}")
# Out:
# Extracting dev orig from gold m2...
# ✅ Extracted 4384 source sentences → /content/ABCN.dev.orig.txt

# %%
# ── Cell 14: Run inference on dev set ─────────────────────────────────────────
import subprocess
import os
import sys

os.chdir(WORK_DIR)

predict_cmd = [
    "python", "predict.py",
    "--model_path",           f"{STAGE1_DIR}/model_best.th",
    "--vocab_path",           VOCAB_PATH,
    "--input_file",           DEV_ORIG,
    "--output_file",          DEV_PRED,
    "--transformer_model",    "mobilebert",
    "--iteration_count",      "5",
    "--min_error_probability","0.1",
    "--min_probability",      "0.0",
    "--additional_confidence","0.0",
    "--special_tokens_fix",   "0",
    "--lowercase_tokens",     "1",
]

print("Running inference on dev set (MOBILEBERT)...")
print(f"  Input : {DEV_ORIG}")
print(f"  Output: {DEV_PRED}")
print()

process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

for line in process.stdout:
    print(line, end="", flush=True)

process.wait()
print("\n✅ Inference done!")

# ── Save dev predictions to Drive ──
import shutil
shutil.copy(DEV_PRED, os.path.join(EVAL_OUT, "dev_predictions.txt"))
print(f"✅ dev_predictions.txt saved to Drive: {EVAL_OUT}")
# Out:
# Running inference on dev set (MOBILEBERT)...
#   Input : /content/ABCN.dev.orig.txt
#   Output: /content/dev_predictions.txt
#
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/1111 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 13148.29it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 5761.41it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 4245.25it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 3314.35it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 3668.49it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 3209.11it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 3386.60it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 2135.05it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 2377.18it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 2272.84it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 1745.32it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 1685.93it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:00, 1559.30it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:00, 1523.14it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 8/1111 [00:00<00:00, 1599.43it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 8/1111 [00:00<00:00, 1561.69it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 9/1111 [00:00<00:00, 1638.97it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 9/1111 [00:00<00:00, 1599.93it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 10/1111 [00:00<00:00, 1653.77it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 10/1111 [00:00<00:00, 1620.67it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 11/1111 [00:00<00:00, 1719.11it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 11/1111 [00:00<00:00, 1698.41it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 12/1111 [00:00<00:00, 1670.32it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 12/1111 [00:00<00:00, 1646.01it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 13/1111 [00:00<00:00, 1726.32it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|          | 13/1111 [00:00<00:00, 1703.30it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:00, 1764.22it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:00, 1741.25it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 1746.80it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 1722.79it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 1704.44it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 1683.53it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 1750.42it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 1735.84it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 1798.67it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 1785.95it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 1850.46it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 1831.24it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 1872.29it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 1854.16it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 1837.38it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 1818.34it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 1755.27it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 1708.22it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 1750.83it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 1736.74it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1740.16it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1722.51it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1764.89it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1752.24it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1719.22it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1704.42it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1740.80it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1727.34it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1744.43it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1730.22it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1707.49it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1694.72it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1653.88it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1645.64it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1617.25it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1609.06it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1638.28it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1629.05it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1637.61it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1630.31it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1657.67it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1650.14it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1683.18it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1620.80it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1646.58it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1638.08it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1660.15it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1651.76it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1679.08it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1671.30it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1699.49it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1677.88it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1699.78it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1693.88it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1700.16it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1691.57it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1716.46it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1710.51it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1717.88it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1710.58it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1660.32it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1654.08it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1676.40it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1635.91it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1594.40it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1587.24it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1608.40it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1602.62it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1569.48it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1564.50it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1589.18it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1585.83it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1609.44it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1605.87it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1629.08it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1622.73it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1645.69it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1642.43it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1663.11it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1657.49it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1670.89it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1663.06it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1681.60it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1676.38it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1694.58it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1688.44it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1704.97it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1690.86it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1707.16it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1701.39it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1709.36it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1702.37it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1720.19it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1713.88it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1730.03it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1724.55it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1741.42it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1736.25it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1752.59it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1749.18it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1731.35it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1725.77it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1737.44it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1727.04it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1731.81it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1726.65it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1740.27it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1735.05it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1750.38it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1744.48it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1760.52it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1756.58it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1771.51it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1766.93it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1782.17it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1778.16it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1783.65it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1778.85it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1793.47it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1787.85it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1792.27it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1786.50it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1801.53it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1797.42it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1810.35it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1807.25it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1821.25it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1815.65it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1829.15it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1824.28it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1837.11it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1833.15it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1845.05it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1839.84it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1853.69it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1849.09it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1852.38it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1846.47it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1850.20it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1845.29it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1843.19it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1837.86it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1849.23it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1844.36it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1827.43it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1822.76it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1798.22it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1793.64it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1805.15it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1801.03it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1813.92it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1810.46it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1821.70it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1817.85it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1830.45it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1827.82it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1840.09it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1836.23it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1846.55it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1841.34it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1852.72it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1848.11it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1858.95it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1853.93it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1820.48it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1816.76it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1763.14it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1759.63it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1716.95it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1713.17it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1720.86it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1718.14it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1725.27it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1721.71it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1732.09it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1716.03it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1718.41it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1714.29it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1698.13it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1694.70it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1704.33it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1701.24it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1710.74it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1706.97it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1716.49it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1713.37it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1723.48it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1719.99it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1708.19it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1692.12it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1693.99it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1690.65it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1699.74it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1697.10it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 1706.16it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 1703.85it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 1689.26it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 1685.47it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 1688.64it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 1685.15it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 1694.03it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 1690.27it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 1697.85it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 1694.84it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 1705.75it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 1703.01it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 1711.80it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 1708.59it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 1717.39it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 1714.68it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 1724.41it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 1721.87it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 1731.13it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 1728.36it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 1737.34it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 1734.88it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 1744.69it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 1741.45it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 1750.81it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 1747.17it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 1756.81it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 1754.21it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 1763.06it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 1761.38it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 1771.53it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 1769.03it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 1777.35it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 1774.76it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 1783.28it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 1780.88it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 1790.37it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 1788.00it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 1798.20it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 1795.34it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 1804.41it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 1801.53it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 1809.69it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 1807.17it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 1815.60it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 1812.12it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 1820.88it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 1818.24it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 1825.88it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 1823.24it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 1831.13it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 1828.34it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 1836.57it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 1833.74it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 1842.29it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 1839.71it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 1847.80it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 1845.32it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 1853.05it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 1850.33it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 1857.66it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 1855.15it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 1863.08it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 1859.06it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 1866.42it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 1864.61it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 1872.94it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 1870.17it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 1878.52it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 1874.63it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 1882.11it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 1879.21it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 1887.08it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 1884.54it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 1892.11it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 1889.31it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 1896.88it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 1894.21it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 1901.74it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 1899.31it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 1907.00it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 1904.58it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 1911.76it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 1909.32it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 1916.66it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 1914.17it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 1921.09it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 1918.56it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 1925.92it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 1923.41it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 1930.86it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 1928.38it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 1936.01it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 1933.51it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 1940.69it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 1938.17it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 1945.45it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 1942.97it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 1950.47it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 1947.95it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 1954.96it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 1952.41it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 1959.63it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 1957.14it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 1964.61it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 1962.19it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 1969.53it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 1966.76it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 1973.86it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 1971.22it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 1978.37it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 1975.44it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 1982.56it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 1979.79it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 1986.81it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 1984.27it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 1991.32it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 1988.92it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 1996.06it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 1993.61it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 2000.19it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 1997.77it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 2004.41it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 2002.03it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 2008.98it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 2006.61it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 2013.05it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 2010.65it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# Loading weights:  16%|█▌        | 175/1111 [00:00<00:00, 2016.59it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.weight]
# Loading weights:  16%|█▌        | 175/1111 [00:00<00:00, 2014.11it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.weight]
# Loading weights:  16%|█▌        | 176/1111 [00:00<00:00, 2021.04it/s, Materializing param=encoder.layer.3.ffn.2.intermediate.dense.bias]
# ...
# Loading weights:  95%|█████████▌| 1059/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.LayerNorm.weight]
# Loading weights:  95%|█████████▌| 1060/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.bias]
# Loading weights:  95%|█████████▌| 1060/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.bias]
# Loading weights:  95%|█████████▌| 1061/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.weight]
# Loading weights:  95%|█████████▌| 1061/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1062/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.bias]
# Loading weights:  96%|█████████▌| 1062/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.bias]
# Loading weights:  96%|█████████▌| 1063/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1063/1111 [00:01<00:00, 874.06it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1064/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1064/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1064/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1065/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1065/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1066/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1066/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1067/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1067/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1068/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1068/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1069/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▌| 1069/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▋| 1070/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1070/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1071/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1071/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1072/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  96%|█████████▋| 1072/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  97%|█████████▋| 1073/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1073/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1074/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1074/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1075/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1075/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1076/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1076/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1077/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1077/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1078/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1078/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1079/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1079/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1080/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1080/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1081/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1081/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1082/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1082/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1083/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  97%|█████████▋| 1083/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  98%|█████████▊| 1084/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1084/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1085/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1085/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1086/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1086/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1087/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1087/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1088/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1088/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1089/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1089/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1090/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1090/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1091/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1091/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 875.24it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 1009.78it/s, Materializing param=encoder.layer.23.output.dense.weight]
# MobileBertModel LOAD REPORT from: google/mobilebert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# mobilebert.embeddings.position_ids         | UNEXPECTED |  |
# cls.predictions.dense.weight               | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 2369
#
# ✅ Inference done!
# ✅ dev_predictions.txt saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage1

# %%
import os
os.system("pip install errant -q")
os.system("python -m spacy download en -q")
print("✅ ERRANT installed!")
# Out:
# ✅ ERRANT installed!

# %%
# ── Cell 15: ERRANT annotation + scoring ──────────────────────────────────────
import os

print("Running ERRANT annotation on dev predictions...")
os.system(f"errant_parallel -orig {DEV_ORIG} -cor {DEV_PRED} -out {DEV_HYP_M2}")

if os.path.exists(DEV_HYP_M2):
    print("✅ dev_hyp.m2 created!")
else:
    print("❌ dev_hyp.m2 not created")

with open(DEV_HYP_M2) as f:
    hyp_count = sum(1 for line in f if line.startswith("S "))
with open(GOLD_M2) as f:
    gold_count = sum(1 for line in f if line.startswith("S "))

print(f"hyp sentences:  {hyp_count}")
print(f"gold sentences: {gold_count}")

if hyp_count != gold_count:
    print("❌ Sentence count mismatch!")
else:
    print("\n========================================")
    print("ERRANT Scores on BEA-2019 Dev Set:")
    print("(Precision / Recall / F0.5)")
    print("========================================")
    result = os.popen(f"errant_compare -hyp {DEV_HYP_M2} -ref {GOLD_M2} 2>&1").read()
    print(result)

# ── Save dev_hyp.m2 to Drive ──
import shutil
shutil.copy(DEV_HYP_M2, os.path.join(EVAL_OUT, "dev_hyp.m2"))
print(f"✅ dev_hyp.m2 saved to Drive: {EVAL_OUT}")
# Out:
# Running ERRANT annotation on dev predictions...
# ✅ dev_hyp.m2 created!
# hyp sentences:  4384
# gold sentences: 4384
#
# ========================================
# ERRANT Scores on BEA-2019 Dev Set:
# (Precision / Recall / F0.5)
# ========================================
#
# =========== Span-Based Correction ============
# TP	FP	FN	Prec	Rec	F0.5
# 958	1946	6503	0.3299	0.1284	0.2511
# ==============================================
#
#
# ✅ dev_hyp.m2 saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage1

# %% [markdown]
# # STAGE 2 DEV RESULT

# %%
# ── Cell 1: Mount Google Drive ────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Cell 2: Verify GPU ──────────────────────────────────────────────────────
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
# ── Cell 3: Paths — UPDATE DRIVE_ROOT to match your Shared Drive ──────────────
import os

# ── EDIT THESE ──
DRIVE_ROOT   = "/content/drive/Shareddrives/gec_thesis/gec_thesis"
DATASETS_DIR = f"{DRIVE_ROOT}/gec_gector_datasets_new"
TEST_DIR     = f"{DRIVE_ROOT}/gec_test_data"
CODE_DIR     = f"{DRIVE_ROOT}/gector_code_mobilebert"
STAGE2_CKPT  = f"{DRIVE_ROOT}/models/stage2/mobilebert"       # folder with model_best.th
EVAL_OUT     = f"{DRIVE_ROOT}/models/eval/mobilebert/stage2"  # evaluation outputs go here

# ── Local working dirs ──
WORK_DIR   = "/content/gector"


STAGE2_DIR = "/content/models/stage2/mobilebert"

for d in [WORK_DIR, STAGE2_DIR, EVAL_OUT]:
    os.makedirs(d, exist_ok=True)

# ── Dataset paths ──
WI_TRAIN   = f"{DATASETS_DIR}/wi_train_gector.txt"
WI_DEV     = f"{DATASETS_DIR}/wi_dev_gector.txt"
VOCAB_PATH = f"{WORK_DIR}/data/output_vocabulary"

# ── Eval paths ──
GOLD_M2     = f"{TEST_DIR}/ABCN.dev.gold.bea19.m2"
DEV_ORIG    = "/content/ABCN.dev.orig.txt"
DEV_PRED    = "/content/dev_predictions.txt"
DEV_HYP_M2  = "/content/dev_hyp.m2"

print("✅ Paths defined!")
print(f"   DRIVE_ROOT  : {DRIVE_ROOT}")
print(f"   CODE_DIR    : {CODE_DIR}")
print(f"   STAGE2_CKPT : {STAGE2_CKPT}")
print(f"   EVAL_OUT    : {EVAL_OUT}")
# Out:
# ✅ Paths defined!
#    DRIVE_ROOT  : /content/drive/Shareddrives/gec_thesis/gec_thesis
#    CODE_DIR    : /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_mobilebert
#    STAGE2_CKPT : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage2/mobilebert
#    EVAL_OUT    : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage2

# %%
# ── Cell 4: Verify all input files ────────────────────────────────────────────
import os

checks = [
    ("W&I Train",                      WI_TRAIN),
    ("W&I Dev",                        WI_DEV),
    ("Gold M2",                        GOLD_M2),
    ("Stage1 model_best.th",           os.path.join(STAGE2_CKPT, "model_best.th")),
    ("Code dir",                       CODE_DIR),
]

all_ok = True
for name, path in checks:
    exists = os.path.exists(path)
    print(f"  {'✅' if exists else '❌'} {name}: {path}")
    if not exists:
        all_ok = False

print()
print("✅ All files found — ready to proceed!" if all_ok else "❌ Fix missing files above before continuing.")
# Out:
#   ✅ W&I Train: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_train_gector.txt
#   ✅ W&I Dev: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_dev_gector.txt
#   ✅ Gold M2: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.dev.gold.bea19.m2
#   ✅ Stage1 model_best.th: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage2/mobilebert/model_best.th
#   ✅ Code dir: /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_mobilebert
#
# ✅ All files found — ready to proceed!

# %%
# ── Cell 5: Copy gector_code_mobilebert to local working dir ──────────────────────
import shutil, os

if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)
shutil.copytree(CODE_DIR, WORK_DIR)
print("✅ Code copied to", WORK_DIR)

for root, dirs, files in os.walk(WORK_DIR):
    for f in files:
        print(os.path.join(root, f).replace(WORK_DIR, ""))
# Out:
# ✅ Code copied to /content/gector
# /README_MOBILEBERT.md
# /requirements.txt
# /predict.py
# /train.py
# /resume_training.py
# /utils/prepare_clc_fce_data.py
# /utils/preprocess_data.py
# /utils/helpers.py
# /data/verb-form-vocab.txt
# /data/output_vocabulary/d_tags.txt
# /data/output_vocabulary/labels.txt
# /data/output_vocabulary/non_padded_namespaces.txt
# /gector/gec_model.py
# /gector/seq2labels_model.py
# /gector/trainer.py
# /gector/datareader.py

# %%
# ── Cell 6: Patch gec_model.py for MOBILBERT ─────────────────────────────────────
new_gec_model = '''
import logging
import os
from time import time

import torch
from transformers import AutoTokenizer

from gector.seq2labels_model import Seq2Labels
from utils.helpers import PAD, UNK, get_target_sent_by_edits

logger = logging.getLogger(__file__)

MODEL_PATHS = {
    "bert":          "bert-base-cased",
    "distilbert":    "distilbert-base-uncased",
    "albert":        "albert-base-v2",
    "roberta":       "roberta-base",
    "gpt2":          "gpt2",
    "transformerxl": "transfo-xl-wt103",
    "xlnet":         "xlnet-base-cased",
    "tinybert":      "huawei-noah/TinyBERT_General_4L_312D",
    "mobilebert":    "google/mobilebert-uncased",
}


class SimpleVocab:
    def __init__(self, vocab_path):
        self.token2idx = {}
        self.idx2token = {}
        labels_file = os.path.join(vocab_path, "labels.txt")
        with open(labels_file, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                token = line.strip()
                self.token2idx[token] = idx
                self.idx2token[idx] = token

    def get_token_index(self, token, namespace=None):
        return self.token2idx.get(token, 0)

    def get_token_from_index(self, idx, namespace=None):
        return self.idx2token.get(idx, UNK)

    def __len__(self):
        return len(self.token2idx)


class GecBERTModel(object):
    def __init__(self, vocab_path=None, model_paths=None,
                 weigths=None,
                 max_len=50,
                 min_len=3,
                 lowercase_tokens=False,
                 log=False,
                 iterations=5,
                 min_probability=0.0,
                 model_name="mobilbert",
                 special_tokens_fix=0,
                 is_ensemble=False,
                 min_error_probability=0.0,
                 confidence=0.0,
                 resolve_cycles=False):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.max_len = max_len
        self.min_len = min_len
        self.lowercase_tokens = lowercase_tokens
        self.min_probability = min_probability
        self.min_error_probability = min_error_probability
        self.log = log
        self.iterations = iterations
        self.confidence = confidence
        self.model_weights = list(map(float, weigths)) if weigths else [1] * len(model_paths)

        self.vocab = SimpleVocab(vocab_path)
        num_labels = len(self.vocab)

        weights_name = MODEL_PATHS.get(model_name, model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(weights_name)

        self.models = []
        for model_path in model_paths:
            model = Seq2Labels(
                encoder_name=weights_name,
                num_labels_classes=num_labels,
                num_detect_classes=4,
                confidence=confidence,
                special_tokens_fix=0,
                tune_bert=False,
            ).to(self.device)
            state = torch.load(model_path, map_location=self.device)
            model.load_state_dict(state)
            model.eval()
            self.models.append(model)

        print(f"✅ Loaded {len(self.models)} model(s) on {self.device}")

    def preprocess(self, token_batch):
        seq_lens = [len(s) for s in token_batch if s]
        if not seq_lens:
            return None

        all_input_ids, all_attention_masks, all_offsets = [], [], []

        for sequence in token_batch:
            tokens = sequence[:self.max_len - 1]
            words  = ["$START"] + tokens

            input_ids = []
            offsets   = []
            for word in words:
                word_ids = self.tokenizer.encode(word, add_special_tokens=False)
                if not word_ids:
                    word_ids = [self.tokenizer.unk_token_id]
                offsets.append(len(input_ids))
                input_ids.extend(word_ids)

            cls_id    = self.tokenizer.cls_token_id
            sep_id    = self.tokenizer.sep_token_id
            input_ids = [cls_id] + input_ids + [sep_id]
            offsets   = [o + 1 for o in offsets]

            all_input_ids.append(input_ids)
            all_offsets.append(offsets)

        max_seq_len  = max(len(ids) for ids in all_input_ids)
        max_word_len = max(len(off) for off in all_offsets)
        pad_id = self.tokenizer.pad_token_id or 0

        padded_ids, attn_masks, padded_offsets = [], [], []
        for ids, offsets in zip(all_input_ids, all_offsets):
            pad_len = max_seq_len - len(ids)
            padded_ids.append(ids + [pad_id] * pad_len)
            attn_masks.append([1] * len(ids) + [0] * pad_len)
            off_pad = max_word_len - len(offsets)
            padded_offsets.append(offsets + [0] * off_pad)

        return {
            "input_ids":      torch.tensor(padded_ids,     dtype=torch.long).to(self.device),
            "attention_mask": torch.tensor(attn_masks,     dtype=torch.long).to(self.device),
            "offsets":        torch.tensor(padded_offsets, dtype=torch.long).to(self.device),
        }

    def predict(self, batch):
        t0 = time()
        predictions = []
        for model in self.models:
            with torch.no_grad():
                output = model.forward(
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    offsets=batch["offsets"],
                )
            predictions.append(output)
        probs, idx, error_probs = self._convert(predictions)
        if self.log:
            print(f"Inference time {time() - t0:.2f}s")
        return probs, idx, error_probs

    def _convert(self, data):
        all_class_probs = torch.zeros_like(data[0]["class_probabilities_labels"])
        error_probs     = torch.zeros_like(data[0]["max_error_probability"])
        for output, weight in zip(data, self.model_weights):
            all_class_probs += weight * output["class_probabilities_labels"] / sum(self.model_weights)
            error_probs     += weight * output["max_error_probability"]      / sum(self.model_weights)
        max_vals = torch.max(all_class_probs, dim=-1)
        return max_vals[0].tolist(), max_vals[1].tolist(), error_probs.tolist()

    def get_token_action(self, token, index, prob, sugg_token):
        if prob < self.min_probability or sugg_token in [UNK, PAD, "$KEEP"]:
            return None
        if sugg_token.startswith("$REPLACE_") or sugg_token.startswith("$TRANSFORM_") or sugg_token == "$DELETE":
            start_pos, end_pos = index, index + 1
        elif sugg_token.startswith("$APPEND_") or sugg_token.startswith("$MERGE_"):
            start_pos = end_pos = index + 1
        else:
            return None
        sugg_token_clear = "" if sugg_token == "$DELETE" else (
            sugg_token if sugg_token.startswith("$TRANSFORM_") or sugg_token.startswith("$MERGE_")
            else sugg_token[sugg_token.index("_") + 1:]
        )
        return start_pos - 1, end_pos - 1, sugg_token_clear, prob

    def postprocess_batch(self, batch, all_probabilities, all_idxs, error_probs):
        all_results = []
        noop_index = self.vocab.get_token_index("$KEEP", "labels")
        for tokens, probabilities, idxs, error_prob in zip(
                batch, all_probabilities, all_idxs, error_probs):
            length = min(len(tokens), self.max_len)
            if max(idxs) == 0 or error_prob < self.min_error_probability:
                all_results.append(tokens)
                continue
            edits = []
            for i in range(length):
                token = tokens[i - 1]
                if idxs[i] == noop_index:
                    continue
                sugg_token = self.vocab.get_token_from_index(idxs[i], "labels")
                action = self.get_token_action(token, i, probabilities[i], sugg_token)
                if action:
                    edits.append(action)
            all_results.append(get_target_sent_by_edits(tokens, edits))
        return all_results

    def update_final_batch(self, final_batch, pred_ids, pred_batch, prev_preds_dict):
        new_pred_ids  = []
        total_updated = 0
        for i, orig_id in enumerate(pred_ids):
            orig       = final_batch[orig_id]
            pred       = pred_batch[i]
            prev_preds = prev_preds_dict[orig_id]
            if orig != pred and pred not in prev_preds:
                final_batch[orig_id] = pred
                new_pred_ids.append(orig_id)
                prev_preds_dict[orig_id].append(pred)
                total_updated += 1
            elif orig != pred and pred in prev_preds:
                final_batch[orig_id] = pred
                total_updated += 1
        return final_batch, new_pred_ids, total_updated

    def handle_batch(self, full_batch):
        final_batch     = full_batch[:]
        batch_size      = len(full_batch)
        prev_preds_dict = {i: [final_batch[i]] for i in range(batch_size)}
        short_ids       = [i for i in range(batch_size) if len(full_batch[i]) < self.min_len]
        pred_ids        = [i for i in range(batch_size) if i not in short_ids]
        total_updates   = 0

        for n_iter in range(self.iterations):
            orig_batch = [final_batch[i] for i in pred_ids]
            sequences  = self.preprocess(orig_batch)
            if not sequences:
                break
            probabilities, idxs, error_probs = self.predict(sequences)
            pred_batch = self.postprocess_batch(orig_batch, probabilities, idxs, error_probs)
            if self.log:
                print(f"Iteration {n_iter + 1}: {round(100*len(pred_ids)/batch_size, 1)}% of sentences active")
            final_batch, pred_ids, cnt = self.update_final_batch(
                final_batch, pred_ids, pred_batch, prev_preds_dict)
            total_updates += cnt
            if not pred_ids:
                break

        return final_batch, total_updates
'''

import os
with open(f"{WORK_DIR}/gector/gec_model.py", "w") as f:
    f.write(new_gec_model)
print("✅ gec_model.py patched for MOBILEBERT!")
# Out:
# ✅ gec_model.py patched for MOBILEBERT!

# %%
content = open(f"{WORK_DIR}/predict.py").read()

content = content.replace(
    "choices=['bert', 'gpt2', 'transformerxl', 'xlnet', 'distilbert', 'roberta', 'albert']",
    "choices=['bert', 'gpt2', 'transformerxl', 'xlnet', 'distilbert', 'roberta', 'albert', 'mobilebert']"
)

with open(f"{WORK_DIR}/predict.py", "w") as f:
    f.write(content)

print("✅ MobileBERT added to predict.py!")
# Out:
# ✅ MobileBERT added to predict.py!

# %%
# ── Cell 6: Restore Stage 2 checkpoint from Drive ────────────────────────────────
import shutil, os

os.makedirs(STAGE2_DIR, exist_ok=True)

print("Restoring Stage 2 best model from Drive...")
src = os.path.join(STAGE2_CKPT, "model_best.th")
dst = os.path.join(STAGE2_DIR, "model_best.th")
if os.path.exists(src):
    shutil.copy(src, dst)
    size = os.path.getsize(dst) / 1e6
    print(f"  ✅ model_best.th ({size:.1f} MB)")
else:
    print(f"  ❌ Not found: {src}")

print("\n✅ Model ready for inference!")
# Out:
# Restoring Stage 2 best model from Drive...
#   ✅ model_best.th (109.1 MB)
#
# ✅ Model ready for inference!

# %%
# ── Cell 13: Extract dev orig sentences from Gold M2 ──────────────────────────
import os

print("Extracting dev orig from gold m2...")
with open(GOLD_M2, encoding='utf-8') as f_in, \
     open(DEV_ORIG, 'w', encoding='utf-8') as f_out:
    for line in f_in:
        if line.startswith("S "):
            f_out.write(line[2:])

with open(DEV_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Extracted {count} source sentences → {DEV_ORIG}")
# Out:
# Extracting dev orig from gold m2...
# ✅ Extracted 4384 source sentences → /content/ABCN.dev.orig.txt

# %%
import os
os.system("pip install errant -q")
os.system("python -m spacy download en -q")
print("✅ ERRANT installed!")
# Out:
# ✅ ERRANT installed!

# %%
# ── Cell 14: Run inference on dev set ─────────────────────────────────────────
import subprocess
import os
import sys

os.chdir(WORK_DIR)

predict_cmd = [
    "python", "predict.py",
    "--model_path",           f"{STAGE2_DIR}/model_best.th",
    "--vocab_path",           VOCAB_PATH,
    "--input_file",           DEV_ORIG,
    "--output_file",          DEV_PRED,
    "--transformer_model",    "mobilebert",
    "--iteration_count",      "5",
    "--min_error_probability","0.1",
    "--min_probability",      "0.0",
    "--additional_confidence","0.0",
    "--special_tokens_fix",   "0",
    "--lowercase_tokens",     "1",
]

print("Running inference on dev set (MOBILEBERT)...")
print(f"  Input : {DEV_ORIG}")
print(f"  Output: {DEV_PRED}")
print()

process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

for line in process.stdout:
    print(line, end="", flush=True)

process.wait()
print("\n✅ Inference done!")

# ── Save dev predictions to Drive ──
import shutil
shutil.copy(DEV_PRED, os.path.join(EVAL_OUT, "dev_predictions.txt"))
print(f"✅ dev_predictions.txt saved to Drive: {EVAL_OUT}")
# Out:
# Running inference on dev set (MOBILEBERT)...
#   Input : /content/ABCN.dev.orig.txt
#   Output: /content/dev_predictions.txt
#
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/1111 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 14716.86it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 5890.88it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 4391.94it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 3647.22it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 3270.84it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 2922.18it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 3222.67it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 3013.69it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 3277.31it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 3040.23it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 3229.29it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 3069.00it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:00, 3273.51it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:00, 3144.83it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 8/1111 [00:00<00:00, 3308.46it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 8/1111 [00:00<00:00, 3176.90it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 9/1111 [00:00<00:00, 3278.22it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 9/1111 [00:00<00:00, 3159.42it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 10/1111 [00:00<00:00, 3207.64it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 10/1111 [00:00<00:00, 3105.51it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 11/1111 [00:00<00:00, 2725.34it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 11/1111 [00:00<00:00, 2641.40it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 12/1111 [00:00<00:00, 2742.57it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 12/1111 [00:00<00:00, 2673.94it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 13/1111 [00:00<00:00, 2549.61it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|          | 13/1111 [00:00<00:00, 2492.27it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:00, 2411.41it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:00, 2370.14it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 2381.32it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 2329.56it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 2394.52it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 2362.66it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 2408.97it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 2370.92it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 2356.06it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 2332.47it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 2156.63it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 2129.20it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 2187.84it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 2162.40it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 2217.76it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 2192.75it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 2213.51it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 2190.34it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 2187.41it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 2165.02it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1848.53it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1832.01it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1875.50it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1859.87it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1693.88it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1679.06it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1612.60it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1603.87it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1641.03it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1628.99it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1647.23it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1636.61it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1661.44it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1649.29it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1679.89it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1669.90it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1700.55it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1690.63it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1722.40it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1712.87it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1743.29it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1733.63it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1695.14it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1686.70it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1697.22it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1688.04it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1715.23it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1707.29it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1736.36it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1728.50it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1697.68it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1691.46it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1716.87it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1698.29it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1722.08it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1713.99it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1544.61it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1539.88it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1519.98it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1512.23it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1535.86it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1531.50it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1556.34it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1549.37it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1572.03it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1567.53it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1591.03it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1586.53it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1556.69it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1550.05it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1570.71it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1565.32it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1584.41it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1554.40it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1571.44it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1555.64it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1518.32it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1513.30it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1526.79it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1521.95it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1541.36it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1536.72it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1533.60it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1528.77it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1535.20it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1529.68it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1546.77it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1542.43it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1513.51it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1508.39it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1519.49it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1516.32it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1508.74it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1503.93it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1518.33it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1515.00it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1531.67it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1527.94it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1544.75it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1541.53it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1531.48it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1528.59it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1539.90it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1535.74it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1551.08it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1547.32it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1563.67it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1559.42it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1575.19it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1571.36it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1586.49it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1582.56it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1598.19it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1594.39it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1609.59it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1606.01it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1620.86it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1617.17it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1632.51it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1628.93it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1644.08it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1640.43it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1655.51it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1650.43it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1664.71it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1661.23it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1675.62it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1672.13it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1687.36it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1683.95it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1697.62it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1694.04it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1708.88it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1705.31it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1720.04it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1716.67it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1731.05it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1727.00it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1741.04it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1737.60it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1751.70it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1748.21it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1762.03it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1758.50it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1771.10it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1767.55it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1781.27it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1777.78it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1790.85it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1787.23it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1800.56it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1797.11it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1810.10it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1806.82it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1820.78it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1818.63it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1834.98it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1833.12it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1849.30it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1847.53it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1860.58it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1857.34it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1870.44it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1866.41it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1879.48it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1875.93it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1887.74it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1883.62it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1895.64it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1892.26it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1904.81it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1901.80it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1916.79it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1914.87it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1930.36it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1926.14it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1938.18it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1934.31it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1945.59it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1941.68it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1953.48it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1950.35it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1960.47it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1956.71it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1968.08it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1964.47it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1977.99it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1975.25it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1984.50it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1980.75it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1992.67it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1989.29it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1999.74it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1996.10it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 2007.28it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 2001.73it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 2011.54it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 2007.46it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 2018.53it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 2015.04it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 2027.42it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 2025.41it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 2035.74it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 2030.84it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 2041.65it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 2038.02it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 2047.00it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 2043.41it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 2052.87it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 2049.10it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 2059.96it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 2056.63it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 2066.94it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 2063.96it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 2075.06it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 2070.97it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 2081.15it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 2078.43it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 2089.76it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 2086.53it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 2096.72it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 2093.39it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 2103.26it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 2099.88it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 2109.79it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 2106.83it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 2117.44it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 2114.16it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 2123.94it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 2119.99it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 2129.21it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 2125.84it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 2135.89it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 2133.24it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 2144.53it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 2141.44it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 2150.27it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 2145.68it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 2154.95it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 2151.75it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 2161.64it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 2158.72it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 2168.93it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 2165.44it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 2174.00it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 2170.48it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 2179.29it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 2175.56it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 2185.09it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 2182.92it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 2190.43it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 2187.20it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 2196.30it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 2192.59it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 2201.87it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 2198.04it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 2206.06it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 2200.87it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 2210.06it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 2206.98it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 2216.60it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 2214.59it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 2223.56it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 2220.42it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 2229.30it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 2226.03it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 2235.02it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 2228.59it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 2235.50it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 2231.41it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 2237.71it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 2234.24it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 2242.50it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 2238.59it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 2243.54it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 2238.80it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 2248.32it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 2242.35it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 2248.90it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 2245.30it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 2254.42it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 2250.43it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 2258.36it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 2255.14it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 2265.79it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 2264.06it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 2272.03it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 2268.52it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 2276.88it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 2273.37it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 2283.95it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 2281.13it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 2289.33it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 2286.00it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 2288.82it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 2283.68it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 2290.68it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 2287.02it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 2296.31it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 2292.48it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 2299.73it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 2297.14it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 2303.04it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 2300.33it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 2309.16it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 2307.30it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 2315.60it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 2312.91it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 2323.01it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 2319.37it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 2326.95it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 2325.04it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 2333.13it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 2329.76it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 2337.03it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 2334.13it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 2341.28it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 2337.42it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 2345.19it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 2342.19it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 2350.08it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 2348.03it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# Loading weights:  16%|█▌        | 175/1111 [00:00<00:00, 2357.66it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.weight]
# Loading weights:  16%|█▌        | 175/1111 [00:00<00:00, 2356.08it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.weight]
# Loading weights:  16%|█▌        | 176/1111 [00:00<00:00, 2363.84it/s, Materializing param=encoder.layer.3.ffn.2.intermediate.dense.bias]
# ...
# Loading weights:  95%|█████████▌| 1059/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.LayerNorm.weight]
# Loading weights:  95%|█████████▌| 1059/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.LayerNorm.weight]
# Loading weights:  95%|█████████▌| 1060/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.bias]
# Loading weights:  95%|█████████▌| 1060/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.bias]
# Loading weights:  95%|█████████▌| 1061/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.weight]
# Loading weights:  95%|█████████▌| 1061/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1062/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.bias]
# Loading weights:  96%|█████████▌| 1062/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.bias]
# Loading weights:  96%|█████████▌| 1063/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1063/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1064/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1064/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1065/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1065/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1066/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1066/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1067/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1067/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1068/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1068/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1069/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▌| 1069/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▋| 1070/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1070/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1071/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1071/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1072/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  96%|█████████▋| 1072/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  97%|█████████▋| 1073/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1073/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1074/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1074/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1075/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1075/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1076/1111 [00:00<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1076/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1077/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1077/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1078/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1078/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1079/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1079/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1080/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1080/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1081/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1081/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1082/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1082/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1083/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  97%|█████████▋| 1083/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  98%|█████████▊| 1084/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1084/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1085/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1085/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1086/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1086/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1087/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1087/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1088/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1088/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1089/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1089/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1090/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1090/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1091/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1091/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 954.10it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 1051.16it/s, Materializing param=encoder.layer.23.output.dense.weight]
# MobileBertModel LOAD REPORT from: google/mobilebert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.dense.weight               | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# mobilebert.embeddings.position_ids         | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 919
#
# ✅ Inference done!
# ✅ dev_predictions.txt saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage2

# %%
# ── Cell 11: ERRANT annotation + scoring ──────────────────────────────────────
import os

print("Running ERRANT annotation on dev predictions...")
os.system(f"errant_parallel -orig {DEV_ORIG} -cor {DEV_PRED} -out {DEV_HYP_M2}")

if os.path.exists(DEV_HYP_M2):
    print("✅ dev_hyp.m2 created!")
else:
    print("❌ dev_hyp.m2 not created")

with open(DEV_HYP_M2) as f:
    hyp_count = sum(1 for line in f if line.startswith("S "))
with open(GOLD_M2) as f:
    gold_count = sum(1 for line in f if line.startswith("S "))

print(f"hyp sentences:  {hyp_count}")
print(f"gold sentences: {gold_count}")

if hyp_count != gold_count:
    print("❌ Sentence count mismatch!")
else:
    print("\n========================================")
    print("ERRANT Scores on BEA-2019 Dev Set:")
    print("(Precision / Recall / F0.5)")
    print("========================================")
    result = os.popen(f"errant_compare -hyp {DEV_HYP_M2} -ref {GOLD_M2} 2>&1").read()
    print(result)

# ── Save dev_hyp.m2 to Drive ──
import shutil
shutil.copy(DEV_HYP_M2, os.path.join(EVAL_OUT, "dev_hyp.m2"))
print(f"✅ dev_hyp.m2 saved to Drive: {EVAL_OUT}")
# Out:
# Running ERRANT annotation on dev predictions...
# ✅ dev_hyp.m2 created!
# hyp sentences:  4384
# gold sentences: 4384
#
# ========================================
# ERRANT Scores on BEA-2019 Dev Set:
# (Precision / Recall / F0.5)
# ========================================
#
# =========== Span-Based Correction ============
# TP	FP	FN	Prec	Rec	F0.5
# 573	514	6888	0.5271	0.0768	0.2426
# ==============================================
#
#
# ✅ dev_hyp.m2 saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage2

# %% [markdown]
# # STAGE 3 DEV RESULT

# %%
# ── Cell 1: Mount Google Drive ────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Cell 2: Verify GPU ──────────────────────────────────────────────────────
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
# ── Cell 3: Paths — UPDATE DRIVE_ROOT to match your Shared Drive ──────────────
import os

# ── EDIT THESE ──
DRIVE_ROOT   = "/content/drive/Shareddrives/gec_thesis/gec_thesis"
DATASETS_DIR = f"{DRIVE_ROOT}/gec_gector_datasets_new"
TEST_DIR     = f"{DRIVE_ROOT}/gec_test_data"
CODE_DIR     = f"{DRIVE_ROOT}/gector_code_mobilebert"
STAGE3_CKPT  = f"{DRIVE_ROOT}/models/stage3/mobilebert"              # folder with model_best.th
EVAL_OUT     = f"{DRIVE_ROOT}/models/eval/mobilebert/stage3"         # evaluation outputs go here

# ── Local working dirs ──
WORK_DIR   = "/content/gector"
STAGE3_DIR = "/content/models/stage3/mobilebert"

for d in [WORK_DIR, STAGE3_DIR, EVAL_OUT]:
    os.makedirs(d, exist_ok=True)

# ── Dataset paths ──
WI_TRAIN   = f"{DATASETS_DIR}/wi_train_gector.txt"
WI_DEV     = f"{DATASETS_DIR}/wi_dev_gector.txt"
VOCAB_PATH = f"{WORK_DIR}/data/output_vocabulary"

# ── Eval paths ──
GOLD_M2     = f"{TEST_DIR}/ABCN.dev.gold.bea19.m2"
DEV_ORIG    = "/content/ABCN.dev.orig.txt"
DEV_PRED    = "/content/dev_predictions.txt"
DEV_HYP_M2  = "/content/dev_hyp.m2"

print("✅ Paths defined!")
print(f"   DRIVE_ROOT  : {DRIVE_ROOT}")
print(f"   CODE_DIR    : {CODE_DIR}")
print(f"   STAGE3_CKPT : {STAGE3_CKPT}")
print(f"   EVAL_OUT    : {EVAL_OUT}")
# Out:
# ✅ Paths defined!
#    DRIVE_ROOT  : /content/drive/Shareddrives/gec_thesis/gec_thesis
#    CODE_DIR    : /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_mobilebert
#    STAGE3_CKPT : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage3/mobilebert
#    EVAL_OUT    : /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage3

# %%
# ── Cell 4: Verify all input files ────────────────────────────────────────────
import os

checks = [
    ("W&I Train",                      WI_TRAIN),
    ("W&I Dev",                        WI_DEV),
    ("Gold M2",                        GOLD_M2),
    ("Stage3 model_best.th",           os.path.join(STAGE3_CKPT, "model_best.th")),
    ("Code dir",                       CODE_DIR),
]

all_ok = True
for name, path in checks:
    exists = os.path.exists(path)
    print(f"  {'✅' if exists else '❌'} {name}: {path}")
    if not exists:
        all_ok = False

print()
print("✅ All files found — ready to proceed!" if all_ok else "❌ Fix missing files above before continuing.")
# Out:
#   ✅ W&I Train: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_train_gector.txt
#   ✅ W&I Dev: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_gector_datasets_new/wi_dev_gector.txt
#   ✅ Gold M2: /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.dev.gold.bea19.m2
#   ✅ Stage3 model_best.th: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/stage3/mobilebert/model_best.th
#   ✅ Code dir: /content/drive/Shareddrives/gec_thesis/gec_thesis/gector_code_mobilebert
#
# ✅ All files found — ready to proceed!

# %%
# ── Cell 5: Copy gector_code_mobilebert to local working dir ──────────────────────
import shutil, os

if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)
shutil.copytree(CODE_DIR, WORK_DIR)
print("✅ Code copied to", WORK_DIR)

for root, dirs, files in os.walk(WORK_DIR):
    for f in files:
        print(os.path.join(root, f).replace(WORK_DIR, ""))
# Out:
# ✅ Code copied to /content/gector
# /predict.py
# /README_MOBILEBERT.md
# /resume_training.py
# /requirements.txt
# /train.py
# /gector/trainer.py
# /gector/datareader.py
# /gector/seq2labels_model.py
# /gector/gec_model.py
# /data/verb-form-vocab.txt
# /data/output_vocabulary/non_padded_namespaces.txt
# /data/output_vocabulary/labels.txt
# /data/output_vocabulary/d_tags.txt
# /utils/preprocess_data.py
# /utils/helpers.py
# /utils/prepare_clc_fce_data.py

# %%
# ── Cell 6: Patch gec_model.py for MOBILEBERT ─────────────────────────────────────
new_gec_model = '''
import logging
import os
from time import time

import torch
from transformers import AutoTokenizer

from gector.seq2labels_model import Seq2Labels
from utils.helpers import PAD, UNK, get_target_sent_by_edits

logger = logging.getLogger(__file__)

MODEL_PATHS = {
    "bert":          "bert-base-cased",
    "distilbert":    "distilbert-base-uncased",
    "albert":        "albert-base-v2",
    "roberta":       "roberta-base",
    "gpt2":          "gpt2",
    "transformerxl": "transfo-xl-wt103",
    "xlnet":         "xlnet-base-cased",
    "tinybert":      "huawei-noah/TinyBERT_General_4L_312D",
    "mobilebert":    "google/mobilebert-uncased",
}


class SimpleVocab:
    def __init__(self, vocab_path):
        self.token2idx = {}
        self.idx2token = {}
        labels_file = os.path.join(vocab_path, "labels.txt")
        with open(labels_file, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                token = line.strip()
                self.token2idx[token] = idx
                self.idx2token[idx] = token

    def get_token_index(self, token, namespace=None):
        return self.token2idx.get(token, 0)

    def get_token_from_index(self, idx, namespace=None):
        return self.idx2token.get(idx, UNK)

    def __len__(self):
        return len(self.token2idx)


class GecBERTModel(object):
    def __init__(self, vocab_path=None, model_paths=None,
                 weigths=None,
                 max_len=50,
                 min_len=3,
                 lowercase_tokens=False,
                 log=False,
                 iterations=5,
                 min_probability=0.0,
                 model_name="mobilebert",
                 special_tokens_fix=0,
                 is_ensemble=False,
                 min_error_probability=0.0,
                 confidence=0.0,
                 resolve_cycles=False):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.max_len = max_len
        self.min_len = min_len
        self.lowercase_tokens = lowercase_tokens
        self.min_probability = min_probability
        self.min_error_probability = min_error_probability
        self.log = log
        self.iterations = iterations
        self.confidence = confidence
        self.model_weights = list(map(float, weigths)) if weigths else [1] * len(model_paths)

        self.vocab = SimpleVocab(vocab_path)
        num_labels = len(self.vocab)

        weights_name = MODEL_PATHS.get(model_name, model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(weights_name)

        self.models = []
        for model_path in model_paths:
            model = Seq2Labels(
                encoder_name=weights_name,
                num_labels_classes=num_labels,
                num_detect_classes=4,
                confidence=confidence,
                special_tokens_fix=0,
                tune_bert=False,
            ).to(self.device)
            state = torch.load(model_path, map_location=self.device)
            model.load_state_dict(state)
            model.eval()
            self.models.append(model)

        print(f"✅ Loaded {len(self.models)} model(s) on {self.device}")

    def preprocess(self, token_batch):
        seq_lens = [len(s) for s in token_batch if s]
        if not seq_lens:
            return None

        all_input_ids, all_attention_masks, all_offsets = [], [], []

        for sequence in token_batch:
            tokens = sequence[:self.max_len - 1]
            words  = ["$START"] + tokens

            input_ids = []
            offsets   = []
            for word in words:
                word_ids = self.tokenizer.encode(word, add_special_tokens=False)
                if not word_ids:
                    word_ids = [self.tokenizer.unk_token_id]
                offsets.append(len(input_ids))
                input_ids.extend(word_ids)

            cls_id    = self.tokenizer.cls_token_id
            sep_id    = self.tokenizer.sep_token_id
            input_ids = [cls_id] + input_ids + [sep_id]
            offsets   = [o + 1 for o in offsets]

            all_input_ids.append(input_ids)
            all_offsets.append(offsets)

        max_seq_len  = max(len(ids) for ids in all_input_ids)
        max_word_len = max(len(off) for off in all_offsets)
        pad_id = self.tokenizer.pad_token_id or 0

        padded_ids, attn_masks, padded_offsets = [], [], []
        for ids, offsets in zip(all_input_ids, all_offsets):
            pad_len = max_seq_len - len(ids)
            padded_ids.append(ids + [pad_id] * pad_len)
            attn_masks.append([1] * len(ids) + [0] * pad_len)
            off_pad = max_word_len - len(offsets)
            padded_offsets.append(offsets + [0] * off_pad)

        return {
            "input_ids":      torch.tensor(padded_ids,     dtype=torch.long).to(self.device),
            "attention_mask": torch.tensor(attn_masks,     dtype=torch.long).to(self.device),
            "offsets":        torch.tensor(padded_offsets, dtype=torch.long).to(self.device),
        }

    def predict(self, batch):
        t0 = time()
        predictions = []
        for model in self.models:
            with torch.no_grad():
                output = model.forward(
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    offsets=batch["offsets"],
                )
            predictions.append(output)
        probs, idx, error_probs = self._convert(predictions)
        if self.log:
            print(f"Inference time {time() - t0:.2f}s")
        return probs, idx, error_probs

    def _convert(self, data):
        all_class_probs = torch.zeros_like(data[0]["class_probabilities_labels"])
        error_probs     = torch.zeros_like(data[0]["max_error_probability"])
        for output, weight in zip(data, self.model_weights):
            all_class_probs += weight * output["class_probabilities_labels"] / sum(self.model_weights)
            error_probs     += weight * output["max_error_probability"]      / sum(self.model_weights)
        max_vals = torch.max(all_class_probs, dim=-1)
        return max_vals[0].tolist(), max_vals[1].tolist(), error_probs.tolist()

    def get_token_action(self, token, index, prob, sugg_token):
        if prob < self.min_probability or sugg_token in [UNK, PAD, "$KEEP"]:
            return None
        if sugg_token.startswith("$REPLACE_") or sugg_token.startswith("$TRANSFORM_") or sugg_token == "$DELETE":
            start_pos, end_pos = index, index + 1
        elif sugg_token.startswith("$APPEND_") or sugg_token.startswith("$MERGE_"):
            start_pos = end_pos = index + 1
        else:
            return None
        sugg_token_clear = "" if sugg_token == "$DELETE" else (
            sugg_token if sugg_token.startswith("$TRANSFORM_") or sugg_token.startswith("$MERGE_")
            else sugg_token[sugg_token.index("_") + 1:]
        )
        return start_pos - 1, end_pos - 1, sugg_token_clear, prob

    def postprocess_batch(self, batch, all_probabilities, all_idxs, error_probs):
        all_results = []
        noop_index = self.vocab.get_token_index("$KEEP", "labels")
        for tokens, probabilities, idxs, error_prob in zip(
                batch, all_probabilities, all_idxs, error_probs):
            length = min(len(tokens), self.max_len)
            if max(idxs) == 0 or error_prob < self.min_error_probability:
                all_results.append(tokens)
                continue
            edits = []
            for i in range(length):
                token = tokens[i - 1]
                if idxs[i] == noop_index:
                    continue
                sugg_token = self.vocab.get_token_from_index(idxs[i], "labels")
                action = self.get_token_action(token, i, probabilities[i], sugg_token)
                if action:
                    edits.append(action)
            all_results.append(get_target_sent_by_edits(tokens, edits))
        return all_results

    def update_final_batch(self, final_batch, pred_ids, pred_batch, prev_preds_dict):
        new_pred_ids  = []
        total_updated = 0
        for i, orig_id in enumerate(pred_ids):
            orig       = final_batch[orig_id]
            pred       = pred_batch[i]
            prev_preds = prev_preds_dict[orig_id]
            if orig != pred and pred not in prev_preds:
                final_batch[orig_id] = pred
                new_pred_ids.append(orig_id)
                prev_preds_dict[orig_id].append(pred)
                total_updated += 1
            elif orig != pred and pred in prev_preds:
                final_batch[orig_id] = pred
                total_updated += 1
        return final_batch, new_pred_ids, total_updated

    def handle_batch(self, full_batch):
        final_batch     = full_batch[:]
        batch_size      = len(full_batch)
        prev_preds_dict = {i: [final_batch[i]] for i in range(batch_size)}
        short_ids       = [i for i in range(batch_size) if len(full_batch[i]) < self.min_len]
        pred_ids        = [i for i in range(batch_size) if i not in short_ids]
        total_updates   = 0

        for n_iter in range(self.iterations):
            orig_batch = [final_batch[i] for i in pred_ids]
            sequences  = self.preprocess(orig_batch)
            if not sequences:
                break
            probabilities, idxs, error_probs = self.predict(sequences)
            pred_batch = self.postprocess_batch(orig_batch, probabilities, idxs, error_probs)
            if self.log:
                print(f"Iteration {n_iter + 1}: {round(100*len(pred_ids)/batch_size, 1)}% of sentences active")
            final_batch, pred_ids, cnt = self.update_final_batch(
                final_batch, pred_ids, pred_batch, prev_preds_dict)
            total_updates += cnt
            if not pred_ids:
                break

        return final_batch, total_updates
'''

import os
with open(f"{WORK_DIR}/gector/gec_model.py", "w") as f:
    f.write(new_gec_model)
print("✅ gec_model.py patched for MOBILEBERT!")
# Out:
# ✅ gec_model.py patched for MOBILEBERT!

# %%
# ── Cell 7: Restore Stage 3 checkpoint from Drive ────────────────────────────────
import shutil, os

os.makedirs(STAGE3_DIR, exist_ok=True)

print("Restoring Stage 3 best model from Drive...")
src = os.path.join(STAGE3_CKPT, "model_best.th")
dst = os.path.join(STAGE3_DIR, "model_best.th")
if os.path.exists(src):
    shutil.copy(src, dst)
    size = os.path.getsize(dst) / 1e6
    print(f"  ✅ model_best.th ({size:.1f} MB)")
else:
    print(f"  ❌ Not found: {src}")

print("\n✅ Model ready for inference!")
# Out:
# Restoring Stage 3 best model from Drive...
#   ✅ model_best.th (109.1 MB)
#
# ✅ Model ready for inference!

# %%
content = open(f"{WORK_DIR}/predict.py").read()

content = content.replace(
    "choices=['bert', 'gpt2', 'transformerxl', 'xlnet', 'distilbert', 'roberta', 'albert']",
    "choices=['bert', 'gpt2', 'transformerxl', 'xlnet', 'distilbert', 'roberta', 'albert', 'mobilebert']"
)

with open(f"{WORK_DIR}/predict.py", "w") as f:
    f.write(content)

print("✅ MobileBERT added to predict.py!")
# Out:
# ✅ MobileBERT added to predict.py!

# %%
# ── Cell 8: BEA-2019 Test Set Inference + submission.zip ──────────────────────
import shutil, os, subprocess, sys, zipfile, time, torch

# ── Paths ──
TEST_ORIG   = f"{TEST_DIR}/ABCN.test.bea19.orig"
PRED_OUTPUT = "/content/predictions.txt"

with open(TEST_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Test input ready ({count} sentences) → {TEST_ORIG}")

# ── Run inference ──
os.chdir(WORK_DIR)
predict_cmd = [
    "python", "predict.py",
    "--model_path",            f"{STAGE3_DIR}/model_best.th",
    "--vocab_path",            VOCAB_PATH,
    "--input_file",            TEST_ORIG,
    "--output_file",           PRED_OUTPUT,
    "--transformer_model",     "mobilebert",
    "--iteration_count",       "5",
    "--min_error_probability", "0.1",
    "--min_probability",       "0.0",
    "--additional_confidence", "0.0",
    "--special_tokens_fix",    "0",
]

# ── GPU RAM before inference ──────────────────────────────────────────────────
print()
print("=" * 50)
print("GPU RAM BEFORE TEST INFERENCE")
print("=" * 50)
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats(0)
    mem_before = torch.cuda.memory_allocated(0) / 1e6
    print(f"  Allocated : {mem_before:.1f} MB")
    print(f"  Reserved  : {torch.cuda.memory_reserved(0) / 1e6:.1f} MB")

# ── Model parameters ──────────────────────────────────────────────────────────
print()
print("=" * 50)
print("MODEL PARAMETERS")
print("=" * 50)
try:
    _state = torch.load(f"{STAGE3_DIR}/model_best.th", map_location="cpu")
    _params = sum(p.numel() for p in _state.values() if hasattr(p, "numel"))
    _size   = sum(p.numel() * p.element_size() for p in _state.values() if hasattr(p, "numel"))
    print(f"  Total parameters : {_params:,}  ({_params/1e6:.2f} M)")
    print(f"  Model size       : {_size / 1e6:.1f} MB (float32)")
    del _state
except Exception as e:
    print(f"  Could not load state dict: {e}")

print()
print("Running inference on BEA-2019 test set (MOBILEBERT)...")
t_start = time.time()
process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="", flush=True)
process.wait()
t_end = time.time()

with open(PRED_OUTPUT) as f:
    pred_count = sum(1 for _ in f)
print(f"\n✅ Predictions written ({pred_count} lines) → {PRED_OUTPUT}")

# ── Inference time + GPU RAM after ───────────────────────────────────────────
elapsed  = t_end - t_start
per_sent = elapsed / count if count > 0 else 0

print()
print("=" * 50)
print("INFERENCE STATS — TEST SET")
print("=" * 50)
print(f"  Sentences        : {count}")
print(f"  Total time       : {elapsed:.1f} s  ({elapsed/60:.2f} min)")
print(f"  Time / sentence  : {per_sent*1000:.1f} ms")
if torch.cuda.is_available():
    mem_after = torch.cuda.memory_allocated(0) / 1e6
    mem_peak  = torch.cuda.max_memory_allocated(0) / 1e6
    print(f"  GPU RAM before   : {mem_before:.1f} MB")
    print(f"  GPU RAM after    : {mem_after:.1f} MB")
    print(f"  GPU RAM peak     : {mem_peak:.1f} MB")
    print(f"  GPU RAM delta    : {mem_after - mem_before:+.1f} MB")

# ── nvidia-smi snapshot ───────────────────────────────────────────────────────
print()
print("=" * 50)
print("GPU USAGE (nvidia-smi)")
print("=" * 50)
_smi = subprocess.run(
    ["nvidia-smi",
     "--query-gpu=index,name,temperature.gpu,utilization.gpu,utilization.memory,memory.used,memory.free,memory.total",
     "--format=csv,noheader,nounits"],
    capture_output=True, text=True
)
if _smi.returncode == 0:
    for line in _smi.stdout.strip().split("\n"):
        idx, name, temp, gpu_util, mem_util, mem_used, mem_free, mem_total = [x.strip() for x in line.split(",")]
        print(f"  GPU {idx}        : {name}")
        print(f"  Temperature  : {temp} °C")
        print(f"  GPU Util     : {gpu_util} %")
        print(f"  Memory Util  : {mem_util} %")
        print(f"  Memory Used  : {mem_used} MB / {mem_total} MB")
        print(f"  Memory Free  : {mem_free} MB")
else:
    print("  nvidia-smi not available:", _smi.stderr)

print()
print("=" * 50)
print("TORCH CUDA MEMORY")
print("=" * 50)
print(f"  Allocated : {round(torch.cuda.memory_allocated(0) / 1e6, 1)} MB")
print(f"  Reserved  : {round(torch.cuda.memory_reserved(0) / 1e6, 1)} MB")

# ── Package submission.zip ──
zip_path = "/content/submission.zip"
with zipfile.ZipFile(zip_path, "w") as z:
    z.write(PRED_OUTPUT, "predictions.txt")
size = os.path.getsize(zip_path) / 1024
print(f"✅ submission.zip ready ({size:.1f} KB) → {zip_path}")
print("Download submission.zip and upload to CodaBench!")

# ── Also save to Drive ──
drive_pred = os.path.join(EVAL_OUT, "test_predictions.txt")
drive_zip  = os.path.join(EVAL_OUT, "submission.zip")
shutil.copy(PRED_OUTPUT, drive_pred)
shutil.copy(zip_path,    drive_zip)
print(f"✅ Also saved to Drive: {drive_zip}")
print(f"   → {EVAL_OUT}")
# Out:
# ✅ Test input ready (4477 sentences) → /content/drive/Shareddrives/gec_thesis/gec_thesis/gec_test_data/ABCN.test.bea19.orig
#
# ==================================================
# GPU RAM BEFORE TEST INFERENCE
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
#
# ==================================================
# MODEL PARAMETERS
# ==================================================
#   Total parameters : 27,149,966  (27.15 M)
#   Model size       : 108.6 MB (float32)
#
# Running inference on BEA-2019 test set (MOBILEBERT)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/1111 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 9892.23it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 4032.98it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 3804.36it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 3176.30it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 3482.68it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 3141.80it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 2360.00it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 2211.89it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 1258.57it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 1212.86it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 1374.51it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 1346.05it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:00, 1493.32it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:00, 1469.40it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 8/1111 [00:00<00:00, 1601.64it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 8/1111 [00:00<00:00, 1475.18it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 9/1111 [00:00<00:00, 1544.11it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 9/1111 [00:00<00:00, 1519.55it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 10/1111 [00:00<00:00, 1635.02it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 10/1111 [00:00<00:00, 1618.05it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 11/1111 [00:00<00:00, 1720.19it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 11/1111 [00:00<00:00, 1693.86it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 12/1111 [00:00<00:00, 1785.51it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 12/1111 [00:00<00:00, 1758.43it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 13/1111 [00:00<00:00, 1846.71it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|          | 13/1111 [00:00<00:00, 1729.72it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:00, 1721.55it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:00, 1703.67it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 1778.40it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 1760.14it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 1602.06it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 1583.35it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 1649.85it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 1628.93it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 1647.95it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 1634.68it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 1616.20it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 1600.56it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 1653.19it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 1639.55it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 1693.37it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 1682.18it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 1744.19it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 1728.51it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 1787.32it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 1779.51it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1831.71it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1816.24it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1704.64it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1690.82it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1650.18it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1637.61it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1675.86it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1666.39it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1655.07it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1643.33it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1680.04it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1670.95it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1594.55it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1584.31it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1617.21it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1607.85it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1641.31it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1633.24it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1591.91it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1582.74it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1550.20it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1486.26it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1508.79it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1493.74it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1519.63it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1508.06it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1533.07it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1526.90it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1529.53it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1522.33it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1524.76it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1517.66it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1539.38it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1533.15it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1540.42it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1534.09it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1544.80it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1538.76it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1500.92it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1495.10it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1511.72it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1506.26it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1528.29it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1522.59it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1538.89it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1534.41it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1501.30it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1494.84it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1483.44it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1477.36it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1495.93it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1491.39it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1496.61it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1490.57it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1497.97it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1492.72it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1511.67it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1508.11it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1527.12it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1524.11it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1499.24it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1493.17it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1509.39it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1505.78it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1432.87it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1428.79it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1446.08it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1442.18it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1459.19it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1455.41it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1471.63it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1467.72it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1475.08it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1463.80it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1435.59it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1431.50it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1446.40it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1432.21it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1441.99it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1437.78it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1451.75it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1448.11it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1463.08it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1459.65it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1474.53it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1472.19it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1461.64it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1457.08it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1471.04it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1467.47it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1479.12it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1475.90it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1483.42it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1465.46it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1478.07it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1474.76it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1451.74it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1448.00it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1458.54it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1455.05it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1467.89it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1464.87it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1474.72it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1466.38it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1470.59it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1466.92it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1453.44it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1450.29it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1462.48it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1459.67it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1467.11it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1464.22it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1476.61it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1473.86it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1486.38it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1483.68it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1496.07it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1493.54it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1505.91it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1503.17it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1516.08it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1513.37it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1525.48it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1522.62it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1521.03it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1516.57it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1469.98it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1467.08it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1477.73it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1474.20it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1459.93it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1456.63it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1466.01it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1463.41it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1473.78it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1471.07it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1483.13it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1480.33it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1488.35it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1485.86it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1495.86it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1493.38it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1415.20it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1412.29it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1422.00it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1420.06it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1429.64it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1427.16it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1429.96it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1427.10it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1436.51it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1433.62it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1442.61it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1440.62it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1426.24it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1423.74it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1429.34it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1427.31it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1435.86it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1433.46it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1442.19it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1440.40it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1449.53it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1447.24it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1455.65it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1453.48it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1462.38it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1460.44it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1469.14it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1466.98it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1475.79it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1473.57it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1464.41it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1461.97it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 1470.33it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 1468.09it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 1476.50it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 1474.27it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 1482.86it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 1480.49it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 1488.43it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 1485.90it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 1493.99it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 1491.42it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 1493.91it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 1491.76it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 1500.34it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 1498.25it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 1490.76it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 1488.42it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 1495.66it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 1493.26it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 1501.31it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 1498.98it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 1505.49it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 1502.97it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 1510.97it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 1508.82it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 1516.92it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 1514.84it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 1523.04it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 1521.05it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 1529.15it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 1527.81it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 1537.80it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 1536.62it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 1546.81it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 1545.27it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 1554.71it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 1552.55it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 1561.07it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 1559.04it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 1568.28it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 1566.39it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 1574.28it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 1572.19it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 1580.20it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 1578.15it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 1585.70it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 1583.38it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 1591.18it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 1588.85it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 1596.89it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 1594.93it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 1602.62it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 1600.68it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 1608.51it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 1605.77it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 1613.02it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 1610.41it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 1617.59it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 1615.05it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 1621.87it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 1619.48it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 1626.30it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 1624.26it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 1631.85it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 1629.83it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 1637.45it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 1635.49it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 1642.86it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 1640.88it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 1648.67it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 1645.61it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 1652.97it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 1650.86it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 1657.81it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 1655.62it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 1662.78it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 1660.64it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 1667.87it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 1665.79it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 1672.79it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 1670.42it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 1677.80it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 1675.88it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 1683.23it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 1680.85it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 1687.99it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 1685.65it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 1692.55it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 1690.43it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 1697.36it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 1695.30it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 1702.08it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 1699.94it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 1706.59it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 1704.45it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 1711.25it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 1709.16it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 1715.63it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 1713.46it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 1720.01it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 1717.87it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 1724.40it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 1722.48it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 1729.20it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 1727.18it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 1734.02it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 1732.07it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 1738.58it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 1736.54it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 1742.78it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 1740.66it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 1746.95it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 1744.85it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 1751.35it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 1749.30it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 1755.32it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 1753.32it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 1759.93it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 1758.01it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 1764.21it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 1762.06it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 1769.79it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 1767.36it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 1774.04it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 1771.88it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 1778.77it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 1776.96it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 1783.33it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 1781.25it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# ...
# Loading weights:  96%|█████████▌| 1063/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1063/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1064/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1064/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1065/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1065/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1066/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1066/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1067/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1067/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1068/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1068/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1069/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▌| 1069/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▋| 1070/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1070/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1071/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1071/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1072/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  96%|█████████▋| 1072/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  97%|█████████▋| 1073/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1073/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1074/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1074/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1075/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1075/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1076/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1076/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1077/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1077/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1078/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1078/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1079/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1079/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1080/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1080/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1081/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1081/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1082/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1082/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1083/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  97%|█████████▋| 1083/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  98%|█████████▊| 1084/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1084/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1085/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1085/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1086/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1086/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1087/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1087/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1088/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1088/1111 [00:01<00:00, 896.03it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1089/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1089/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1089/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1090/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1090/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1091/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1091/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 867.79it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 1025.70it/s, Materializing param=encoder.layer.23.output.dense.weight]
# MobileBertModel LOAD REPORT from: google/mobilebert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.dense.weight               | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# mobilebert.embeddings.position_ids         | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 1796
#
# ✅ Predictions written (4477 lines) → /content/predictions.txt
#
# ==================================================
# INFERENCE STATS — TEST SET
# ==================================================
#   Sentences        : 4477
#   Total time       : 37.6 s  (0.63 min)
#   Time / sentence  : 8.4 ms
#   GPU RAM before   : 0.0 MB
#   GPU RAM after    : 0.0 MB
#   GPU RAM peak     : 0.0 MB
#   GPU RAM delta    : +0.0 MB
#
# ==================================================
# GPU USAGE (nvidia-smi)
# ==================================================
#   GPU 0        : Tesla T4
#   Temperature  : 43 °C
#   GPU Util     : 0 %
#   Memory Util  : 0 %
#   Memory Used  : 3 MB / 15360 MB
#   Memory Free  : 14910 MB
#
# ==================================================
# TORCH CUDA MEMORY
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
# ✅ submission.zip ready (428.4 KB) → /content/submission.zip
# Download submission.zip and upload to CodaBench!
# ✅ Also saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage3/submission.zip
#    → /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage3

# %%
# ── Cell 9: Extract dev orig sentences from Gold M2 ──────────────────────────
import os

print("Extracting dev orig from gold m2...")
with open(GOLD_M2, encoding='utf-8') as f_in, \
     open(DEV_ORIG, 'w', encoding='utf-8') as f_out:
    for line in f_in:
        if line.startswith("S "):
            f_out.write(line[2:])

with open(DEV_ORIG) as f:
    count = sum(1 for _ in f)
print(f"✅ Extracted {count} source sentences → {DEV_ORIG}")
# Out:
# Extracting dev orig from gold m2...
# ✅ Extracted 4384 source sentences → /content/ABCN.dev.orig.txt

# %%
# ── Cell 10: Run inference on dev set ─────────────────────────────────────────
import subprocess, os, sys, time, torch

os.chdir(WORK_DIR)

predict_cmd = [
    "python", "predict.py",
    "--model_path",           f"{STAGE3_DIR}/model_best.th",
    "--vocab_path",           VOCAB_PATH,
    "--input_file",           DEV_ORIG,
    "--output_file",          DEV_PRED,
    "--transformer_model",    "mobilebert",
    "--iteration_count",      "5",
    "--min_error_probability","0.1",
    "--min_probability",      "0.0",
    "--additional_confidence","0.0",
    "--special_tokens_fix",   "0",
    "--lowercase_tokens",     "1",
]

# ── GPU RAM before inference ──────────────────────────────────────────────────
print("=" * 50)
print("GPU RAM BEFORE DEV INFERENCE")
print("=" * 50)
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats(0)
    mem_before_dev = torch.cuda.memory_allocated(0) / 1e6
    print(f"  Allocated : {mem_before_dev:.1f} MB")
    print(f"  Reserved  : {torch.cuda.memory_reserved(0) / 1e6:.1f} MB")

# ── Model parameters ──────────────────────────────────────────────────────────
print("=" * 50)
print("MODEL PARAMETERS")
print("=" * 50)
try:
    _state = torch.load(f"{STAGE3_DIR}/model_best.th", map_location="cpu")
    _params = sum(p.numel() for p in _state.values() if hasattr(p, "numel"))
    print(f"  Total parameters : {_params:,}  ({_params/1e6:.2f} M)")
    del _state
except Exception as e:
    print(f"  Could not load state dict: {e}")
print()

print("Running inference on dev set (MOBILEBERT)...")
print(f"  Input : {DEV_ORIG}")
print(f"  Output: {DEV_PRED}")
t_start = time.time()
process = subprocess.Popen(
    predict_cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

for line in process.stdout:
    print(line, end="", flush=True)

process.wait()
t_end = time.time()
print("\n✅ Inference done!")

# ── Count sentences ───────────────────────────────────────────────────────────
with open(DEV_ORIG) as f:
    dev_count = sum(1 for _ in f)

elapsed_dev  = t_end - t_start
per_sent_dev = elapsed_dev / dev_count if dev_count > 0 else 0

# ── Inference time + GPU RAM after ───────────────────────────────────────────
print()
print("=" * 50)
print("INFERENCE STATS — DEV SET")
print("=" * 50)
print(f"  Sentences        : {dev_count}")
print(f"  Total time       : {elapsed_dev:.1f} s  ({elapsed_dev/60:.2f} min)")
print(f"  Time / sentence  : {per_sent_dev*1000:.1f} ms")
if torch.cuda.is_available():
    mem_after_dev = torch.cuda.memory_allocated(0) / 1e6
    mem_peak_dev  = torch.cuda.max_memory_allocated(0) / 1e6
    print(f"  GPU RAM before   : {mem_before_dev:.1f} MB")
    print(f"  GPU RAM after    : {mem_after_dev:.1f} MB")
    print(f"  GPU RAM peak     : {mem_peak_dev:.1f} MB")
    print(f"  GPU RAM delta    : {mem_after_dev - mem_before_dev:+.1f} MB")

# ── nvidia-smi snapshot ───────────────────────────────────────────────────────
print()
print("=" * 50)
print("GPU USAGE (nvidia-smi)")
print("=" * 50)
_smi = subprocess.run(
    ["nvidia-smi",
     "--query-gpu=index,name,temperature.gpu,utilization.gpu,utilization.memory,memory.used,memory.free,memory.total",
     "--format=csv,noheader,nounits"],
    capture_output=True, text=True
)
if _smi.returncode == 0:
    for line in _smi.stdout.strip().split("\n"):
        idx, name, temp, gpu_util, mem_util, mem_used, mem_free, mem_total = [x.strip() for x in line.split(",")]
        print(f"  GPU {idx}        : {name}")
        print(f"  Temperature  : {temp} °C")
        print(f"  GPU Util     : {gpu_util} %")
        print(f"  Memory Util  : {mem_util} %")
        print(f"  Memory Used  : {mem_used} MB / {mem_total} MB")
        print(f"  Memory Free  : {mem_free} MB")
else:
    print("  nvidia-smi not available:", _smi.stderr)

print()
print("=" * 50)
print("TORCH CUDA MEMORY")
print("=" * 50)
print(f"  Allocated : {round(torch.cuda.memory_allocated(0) / 1e6, 1)} MB")
print(f"  Reserved  : {round(torch.cuda.memory_reserved(0) / 1e6, 1)} MB")

# ── Save dev predictions to Drive ──
import shutil
shutil.copy(DEV_PRED, os.path.join(EVAL_OUT, "dev_predictions.txt"))
print(f"✅ dev_predictions.txt saved to Drive: {EVAL_OUT}")
# Out:
# ==================================================
# GPU RAM BEFORE DEV INFERENCE
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
# ==================================================
# MODEL PARAMETERS
# ==================================================
#   Total parameters : 27,149,966  (27.15 M)
#
# Running inference on dev set (MOBILEBERT)...
#   Input : /content/ABCN.dev.orig.txt
#   Output: /content/dev_predictions.txt
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/1111 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 12865.96it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 1/1111 [00:00<00:00, 5302.53it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 4733.98it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 2/1111 [00:00<00:00, 3642.47it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 3980.67it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 3/1111 [00:00<00:00, 3655.70it/s, Materializing param=embeddings.embedding_transformation.bias]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 3701.13it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 4/1111 [00:00<00:00, 3430.92it/s, Materializing param=embeddings.embedding_transformation.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 3696.07it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   0%|          | 5/1111 [00:00<00:00, 3509.88it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 3682.98it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 6/1111 [00:00<00:00, 3476.90it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:01, 972.29it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 7/1111 [00:00<00:01, 956.98it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   1%|          | 8/1111 [00:00<00:01, 1030.73it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 8/1111 [00:00<00:01, 1013.09it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   1%|          | 9/1111 [00:00<00:01, 1048.11it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 9/1111 [00:00<00:01, 1030.12it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   1%|          | 10/1111 [00:00<00:01, 1077.53it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 10/1111 [00:00<00:01, 959.99it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   1%|          | 11/1111 [00:00<00:01, 1023.77it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 11/1111 [00:00<00:01, 1012.72it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   1%|          | 12/1111 [00:00<00:01, 1065.49it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 12/1111 [00:00<00:01, 1010.45it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   1%|          | 13/1111 [00:00<00:01, 1060.84it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|          | 13/1111 [00:00<00:01, 1051.63it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:01, 1065.28it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 14/1111 [00:00<00:01, 1056.82it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 1115.53it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 15/1111 [00:00<00:00, 1105.67it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 1159.39it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   1%|▏         | 16/1111 [00:00<00:00, 1149.36it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 1166.00it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 17/1111 [00:00<00:00, 1156.41it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 1201.40it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 18/1111 [00:00<00:00, 1190.34it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.bias]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 1206.01it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 19/1111 [00:00<00:00, 1196.82it/s, Materializing param=encoder.layer.0.bottleneck.attention.LayerNorm.weight]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 1223.22it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 20/1111 [00:00<00:00, 1214.21it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.bias]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 1256.93it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 21/1111 [00:00<00:00, 1248.85it/s, Materializing param=encoder.layer.0.bottleneck.attention.dense.weight]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 1216.89it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 22/1111 [00:00<00:00, 1207.88it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.bias]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 1245.82it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 23/1111 [00:00<00:00, 1237.77it/s, Materializing param=encoder.layer.0.bottleneck.input.LayerNorm.weight]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1276.29it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 24/1111 [00:00<00:00, 1269.32it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.bias]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1305.95it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 25/1111 [00:00<00:00, 1298.45it/s, Materializing param=encoder.layer.0.bottleneck.input.dense.weight]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1332.79it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 26/1111 [00:00<00:00, 1324.91it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.bias]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1329.79it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   2%|▏         | 27/1111 [00:00<00:00, 1321.69it/s, Materializing param=encoder.layer.0.ffn.0.intermediate.dense.weight]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1352.66it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 28/1111 [00:00<00:00, 1344.99it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1377.66it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 29/1111 [00:00<00:00, 1369.87it/s, Materializing param=encoder.layer.0.ffn.0.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1403.39it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 30/1111 [00:00<00:00, 1398.97it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.bias]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1431.14it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 31/1111 [00:00<00:00, 1425.74it/s, Materializing param=encoder.layer.0.ffn.0.output.dense.weight]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1447.78it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 32/1111 [00:00<00:00, 1439.83it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.bias]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1472.01it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 33/1111 [00:00<00:00, 1464.17it/s, Materializing param=encoder.layer.0.ffn.1.intermediate.dense.weight]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1495.01it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 34/1111 [00:00<00:00, 1473.48it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1494.81it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 35/1111 [00:00<00:00, 1487.88it/s, Materializing param=encoder.layer.0.ffn.1.output.LayerNorm.weight]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1512.63it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 36/1111 [00:00<00:00, 1505.25it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.bias]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1482.10it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 37/1111 [00:00<00:00, 1475.31it/s, Materializing param=encoder.layer.0.ffn.1.output.dense.weight]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1499.74it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   3%|▎         | 38/1111 [00:00<00:00, 1493.74it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.bias]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1517.80it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 39/1111 [00:00<00:00, 1511.15it/s, Materializing param=encoder.layer.0.ffn.2.intermediate.dense.weight]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1534.89it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 40/1111 [00:00<00:00, 1527.01it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1551.08it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▎         | 41/1111 [00:00<00:00, 1544.21it/s, Materializing param=encoder.layer.0.ffn.2.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1567.00it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 42/1111 [00:00<00:00, 1557.70it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.bias]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1578.03it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 43/1111 [00:00<00:00, 1570.78it/s, Materializing param=encoder.layer.0.ffn.2.output.dense.weight]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1591.85it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 44/1111 [00:00<00:00, 1584.79it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1595.18it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 45/1111 [00:00<00:00, 1587.91it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1608.12it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 46/1111 [00:00<00:00, 1601.01it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1621.42it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 47/1111 [00:00<00:00, 1614.52it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1634.00it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 48/1111 [00:00<00:00, 1628.28it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.bias]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1634.09it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   4%|▍         | 49/1111 [00:00<00:00, 1627.58it/s, Materializing param=encoder.layer.0.output.bottleneck.LayerNorm.weight]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1629.29it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 50/1111 [00:00<00:00, 1623.22it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.bias]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1643.75it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 51/1111 [00:00<00:00, 1637.58it/s, Materializing param=encoder.layer.0.output.bottleneck.dense.weight]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1657.11it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 52/1111 [00:00<00:00, 1651.68it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1671.04it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 53/1111 [00:00<00:00, 1665.57it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1664.93it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 54/1111 [00:00<00:00, 1659.10it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1675.87it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▍         | 55/1111 [00:00<00:00, 1670.13it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1676.24it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 56/1111 [00:00<00:00, 1669.94it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1690.20it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 57/1111 [00:00<00:00, 1685.17it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1683.81it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 58/1111 [00:00<00:00, 1678.82it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1697.47it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 59/1111 [00:00<00:00, 1692.30it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1711.94it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 60/1111 [00:00<00:00, 1708.86it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1708.31it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   5%|▌         | 61/1111 [00:00<00:00, 1701.87it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1677.75it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 62/1111 [00:00<00:00, 1674.08it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1650.26it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 63/1111 [00:00<00:00, 1643.83it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1640.76it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 64/1111 [00:00<00:00, 1636.50it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.bias]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1651.30it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 65/1111 [00:00<00:00, 1646.02it/s, Materializing param=encoder.layer.1.bottleneck.attention.LayerNorm.weight]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1661.10it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 66/1111 [00:00<00:00, 1656.68it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.bias]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1653.52it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 67/1111 [00:00<00:00, 1648.90it/s, Materializing param=encoder.layer.1.bottleneck.attention.dense.weight]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1658.18it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 68/1111 [00:00<00:00, 1653.20it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.bias]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1661.64it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▌         | 69/1111 [00:00<00:00, 1657.17it/s, Materializing param=encoder.layer.1.bottleneck.input.LayerNorm.weight]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1672.41it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 70/1111 [00:00<00:00, 1668.13it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.bias]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1649.38it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 71/1111 [00:00<00:00, 1644.47it/s, Materializing param=encoder.layer.1.bottleneck.input.dense.weight]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1659.39it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   6%|▋         | 72/1111 [00:00<00:00, 1656.04it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.bias]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1670.49it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 73/1111 [00:00<00:00, 1665.96it/s, Materializing param=encoder.layer.1.ffn.0.intermediate.dense.weight]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1680.89it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 74/1111 [00:00<00:00, 1676.62it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1691.63it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 75/1111 [00:00<00:00, 1689.18it/s, Materializing param=encoder.layer.1.ffn.0.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1687.28it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 76/1111 [00:00<00:00, 1683.04it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.bias]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1696.42it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 77/1111 [00:00<00:00, 1692.68it/s, Materializing param=encoder.layer.1.ffn.0.output.dense.weight]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1705.95it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 78/1111 [00:00<00:00, 1702.75it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.bias]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1716.55it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 79/1111 [00:00<00:00, 1712.69it/s, Materializing param=encoder.layer.1.ffn.1.intermediate.dense.weight]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1636.48it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 80/1111 [00:00<00:00, 1632.56it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1635.06it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 81/1111 [00:00<00:00, 1631.30it/s, Materializing param=encoder.layer.1.ffn.1.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1620.09it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 82/1111 [00:00<00:00, 1616.93it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.bias]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1563.05it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   7%|▋         | 83/1111 [00:00<00:00, 1558.51it/s, Materializing param=encoder.layer.1.ffn.1.output.dense.weight]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1570.88it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 84/1111 [00:00<00:00, 1567.89it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.bias]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1575.29it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 85/1111 [00:00<00:00, 1572.46it/s, Materializing param=encoder.layer.1.ffn.2.intermediate.dense.weight]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1583.73it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 86/1111 [00:00<00:00, 1580.63it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1593.39it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 87/1111 [00:00<00:00, 1591.55it/s, Materializing param=encoder.layer.1.ffn.2.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1603.65it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 88/1111 [00:00<00:00, 1600.37it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.bias]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1513.77it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 89/1111 [00:00<00:00, 1510.64it/s, Materializing param=encoder.layer.1.ffn.2.output.dense.weight]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1523.00it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 90/1111 [00:00<00:00, 1519.94it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1531.84it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 91/1111 [00:00<00:00, 1506.73it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1509.59it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 92/1111 [00:00<00:00, 1506.72it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1517.21it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 93/1111 [00:00<00:00, 1514.60it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1525.37it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   8%|▊         | 94/1111 [00:00<00:00, 1505.99it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.bias]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1515.24it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 95/1111 [00:00<00:00, 1512.55it/s, Materializing param=encoder.layer.1.output.bottleneck.LayerNorm.weight]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1487.80it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 96/1111 [00:00<00:00, 1485.19it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.bias]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1494.99it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▊         | 97/1111 [00:00<00:00, 1491.75it/s, Materializing param=encoder.layer.1.output.bottleneck.dense.weight]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1493.23it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 98/1111 [00:00<00:00, 1490.48it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1500.24it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 99/1111 [00:00<00:00, 1497.69it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1498.95it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 100/1111 [00:00<00:00, 1495.74it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1498.60it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 101/1111 [00:00<00:00, 1495.81it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1504.25it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 102/1111 [00:00<00:00, 1501.54it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1503.46it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 103/1111 [00:00<00:00, 1500.65it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1498.00it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 104/1111 [00:00<00:00, 1495.38it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1484.04it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:   9%|▉         | 105/1111 [00:00<00:00, 1454.87it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1462.88it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 106/1111 [00:00<00:00, 1460.18it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1461.95it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 107/1111 [00:00<00:00, 1459.27it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1467.93it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 108/1111 [00:00<00:00, 1465.56it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1474.30it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 109/1111 [00:00<00:00, 1471.79it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1475.08it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 110/1111 [00:00<00:00, 1472.91it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.bias]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 1482.37it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|▉         | 111/1111 [00:00<00:00, 1480.46it/s, Materializing param=encoder.layer.2.bottleneck.attention.LayerNorm.weight]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 1489.39it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 112/1111 [00:00<00:00, 1487.36it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.bias]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 1495.75it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 113/1111 [00:00<00:00, 1493.32it/s, Materializing param=encoder.layer.2.bottleneck.attention.dense.weight]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 1501.98it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 114/1111 [00:00<00:00, 1499.77it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.bias]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 1472.17it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 115/1111 [00:00<00:00, 1469.55it/s, Materializing param=encoder.layer.2.bottleneck.input.LayerNorm.weight]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 1459.30it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  10%|█         | 116/1111 [00:00<00:00, 1457.23it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.bias]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 1465.70it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 117/1111 [00:00<00:00, 1463.71it/s, Materializing param=encoder.layer.2.bottleneck.input.dense.weight]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 1467.17it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 118/1111 [00:00<00:00, 1454.19it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.bias]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 1454.06it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 119/1111 [00:00<00:00, 1452.23it/s, Materializing param=encoder.layer.2.ffn.0.intermediate.dense.weight]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 1457.68it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 120/1111 [00:00<00:00, 1455.26it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.bias]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 1457.46it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 121/1111 [00:00<00:00, 1446.53it/s, Materializing param=encoder.layer.2.ffn.0.output.LayerNorm.weight]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 1451.54it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 122/1111 [00:00<00:00, 1446.86it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.bias]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 1453.75it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 123/1111 [00:00<00:00, 1452.12it/s, Materializing param=encoder.layer.2.ffn.0.output.dense.weight]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 1460.97it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█         | 124/1111 [00:00<00:00, 1459.40it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.bias]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 1447.75it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 125/1111 [00:00<00:00, 1445.27it/s, Materializing param=encoder.layer.2.ffn.1.intermediate.dense.weight]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 1453.46it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 126/1111 [00:00<00:00, 1451.80it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.bias]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 1459.98it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  11%|█▏        | 127/1111 [00:00<00:00, 1458.29it/s, Materializing param=encoder.layer.2.ffn.1.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 1466.12it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 128/1111 [00:00<00:00, 1465.06it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.bias]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 1474.02it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 129/1111 [00:00<00:00, 1473.00it/s, Materializing param=encoder.layer.2.ffn.1.output.dense.weight]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 1482.66it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 130/1111 [00:00<00:00, 1481.83it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 1489.02it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 131/1111 [00:00<00:00, 1487.93it/s, Materializing param=encoder.layer.2.ffn.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 1496.27it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 132/1111 [00:00<00:00, 1494.69it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 1502.35it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 133/1111 [00:00<00:00, 1500.97it/s, Materializing param=encoder.layer.2.ffn.2.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 1510.06it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 134/1111 [00:00<00:00, 1509.08it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.bias]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 1517.52it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 135/1111 [00:00<00:00, 1516.46it/s, Materializing param=encoder.layer.2.ffn.2.output.dense.weight]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 1524.37it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 136/1111 [00:00<00:00, 1522.14it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 1530.01it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 137/1111 [00:00<00:00, 1528.80it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 1538.14it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 138/1111 [00:00<00:00, 1537.15it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 1546.61it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 139/1111 [00:00<00:00, 1545.16it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 1552.49it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 140/1111 [00:00<00:00, 1551.40it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.bias]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 1560.60it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 141/1111 [00:00<00:00, 1558.91it/s, Materializing param=encoder.layer.2.output.bottleneck.LayerNorm.weight]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 1566.51it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 142/1111 [00:00<00:00, 1565.50it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.bias]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 1573.93it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 143/1111 [00:00<00:00, 1572.51it/s, Materializing param=encoder.layer.2.output.bottleneck.dense.weight]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 1580.62it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 144/1111 [00:00<00:00, 1578.98it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 1587.33it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 145/1111 [00:00<00:00, 1585.97it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 1594.13it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 146/1111 [00:00<00:00, 1592.47it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 1600.74it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 147/1111 [00:00<00:00, 1598.48it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 1605.40it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 148/1111 [00:00<00:00, 1604.06it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 1611.66it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  13%|█▎        | 149/1111 [00:00<00:00, 1610.24it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 1619.05it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 150/1111 [00:00<00:00, 1616.78it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 1624.39it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 151/1111 [00:00<00:00, 1622.45it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 1630.24it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▎        | 152/1111 [00:00<00:00, 1628.72it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 1636.59it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 153/1111 [00:00<00:00, 1635.58it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 1642.57it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 154/1111 [00:00<00:00, 1640.95it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 1648.29it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 155/1111 [00:00<00:00, 1646.34it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 1653.30it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 156/1111 [00:00<00:00, 1651.58it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.bias]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 1658.83it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 157/1111 [00:00<00:00, 1656.96it/s, Materializing param=encoder.layer.3.bottleneck.attention.LayerNorm.weight]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 1664.18it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 158/1111 [00:00<00:00, 1662.49it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.bias]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 1669.56it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 159/1111 [00:00<00:00, 1667.83it/s, Materializing param=encoder.layer.3.bottleneck.attention.dense.weight]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 1675.03it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 160/1111 [00:00<00:00, 1672.90it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.bias]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 1679.83it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  14%|█▍        | 161/1111 [00:00<00:00, 1678.18it/s, Materializing param=encoder.layer.3.bottleneck.input.LayerNorm.weight]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 1686.50it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 162/1111 [00:00<00:00, 1685.52it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.bias]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 1692.31it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 163/1111 [00:00<00:00, 1690.42it/s, Materializing param=encoder.layer.3.bottleneck.input.dense.weight]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 1697.49it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 164/1111 [00:00<00:00, 1696.34it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.bias]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 1703.60it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 165/1111 [00:00<00:00, 1701.87it/s, Materializing param=encoder.layer.3.ffn.0.intermediate.dense.weight]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 1709.05it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▍        | 166/1111 [00:00<00:00, 1707.26it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 1714.78it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 167/1111 [00:00<00:00, 1713.78it/s, Materializing param=encoder.layer.3.ffn.0.output.LayerNorm.weight]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 1722.25it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 168/1111 [00:00<00:00, 1720.55it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.bias]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 1727.49it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 169/1111 [00:00<00:00, 1725.88it/s, Materializing param=encoder.layer.3.ffn.0.output.dense.weight]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 1733.33it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 170/1111 [00:00<00:00, 1731.55it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.bias]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 1738.39it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 171/1111 [00:00<00:00, 1736.89it/s, Materializing param=encoder.layer.3.ffn.1.intermediate.dense.weight]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 1743.90it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  15%|█▌        | 172/1111 [00:00<00:00, 1742.91it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.bias]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 1750.59it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 173/1111 [00:00<00:00, 1749.29it/s, Materializing param=encoder.layer.3.ffn.1.output.LayerNorm.weight]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 1756.97it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# Loading weights:  16%|█▌        | 174/1111 [00:00<00:00, 1755.39it/s, Materializing param=encoder.layer.3.ffn.1.output.dense.bias]
# ...
# Loading weights:  96%|█████████▌| 1062/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.bias]
# Loading weights:  96%|█████████▌| 1062/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.bias]
# Loading weights:  96%|█████████▌| 1063/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1063/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.bottleneck.dense.weight]
# Loading weights:  96%|█████████▌| 1064/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1064/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.dense.bias]
# Loading weights:  96%|█████████▌| 1065/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1065/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.22.output.dense.weight]
# Loading weights:  96%|█████████▌| 1066/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1066/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 1067/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1067/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 1068/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1068/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.dense.bias]
# Loading weights:  96%|█████████▌| 1069/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▌| 1069/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.output.dense.weight]
# Loading weights:  96%|█████████▋| 1070/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1070/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.key.bias]
# Loading weights:  96%|█████████▋| 1071/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1071/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.key.weight]
# Loading weights:  96%|█████████▋| 1072/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  96%|█████████▋| 1072/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.query.bias]
# Loading weights:  97%|█████████▋| 1073/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1073/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.query.weight]
# Loading weights:  97%|█████████▋| 1074/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1074/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.value.bias]
# Loading weights:  97%|█████████▋| 1075/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1075/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.attention.self.value.weight]
# Loading weights:  97%|█████████▋| 1076/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1076/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1077/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1077/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1078/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1078/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.bias]
# Loading weights:  97%|█████████▋| 1079/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1079/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.attention.dense.weight]
# Loading weights:  97%|█████████▋| 1080/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1080/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 1081/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1081/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 1082/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1082/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.bias]
# Loading weights:  97%|█████████▋| 1083/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  97%|█████████▋| 1083/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.bottleneck.input.dense.weight]
# Loading weights:  98%|█████████▊| 1084/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1084/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1085/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1085/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1086/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1086/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1087/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1087/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1088/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1088/1111 [00:00<00:00, 937.19it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1089/1111 [00:00<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.bias]
# Loading weights:  98%|█████████▊| 1089/1111 [00:00<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1089/1111 [00:00<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.0.output.dense.weight]
# Loading weights:  98%|█████████▊| 1090/1111 [00:00<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1090/1111 [00:00<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.bias]
# Loading weights:  98%|█████████▊| 1091/1111 [00:00<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1091/1111 [00:00<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.intermediate.dense.weight]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1092/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1093/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  98%|█████████▊| 1094/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.bias]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1095/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.1.output.dense.weight]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1096/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.bias]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▊| 1097/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1098/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1099/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1100/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.bias]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1101/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.ffn.2.output.dense.weight]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1102/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.intermediate.dense.bias]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1103/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.intermediate.dense.weight]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1104/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.LayerNorm.bias]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights:  99%|█████████▉| 1105/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1106/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.bias]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1107/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.LayerNorm.weight]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1108/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.bias]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1109/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.bottleneck.dense.weight]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|█████████▉| 1110/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.dense.bias]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 974.18it/s, Materializing param=encoder.layer.23.output.dense.weight]
# Loading weights: 100%|██████████| 1111/1111 [00:01<00:00, 1083.98it/s, Materializing param=encoder.layer.23.output.dense.weight]
# MobileBertModel LOAD REPORT from: google/mobilebert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.dense.weight               | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# mobilebert.embeddings.position_ids         | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Loaded 1 model(s) on cuda:0
# Produced overall corrections: 1837
#
# ✅ Inference done!
#
# ==================================================
# INFERENCE STATS — DEV SET
# ==================================================
#   Sentences        : 4384
#   Total time       : 24.1 s  (0.40 min)
#   Time / sentence  : 5.5 ms
#   GPU RAM before   : 0.0 MB
#   GPU RAM after    : 0.0 MB
#   GPU RAM peak     : 0.0 MB
#   GPU RAM delta    : +0.0 MB
#
# ==================================================
# GPU USAGE (nvidia-smi)
# ==================================================
#   GPU 0        : Tesla T4
#   Temperature  : 47 °C
#   GPU Util     : 0 %
#   Memory Util  : 0 %
#   Memory Used  : 3 MB / 15360 MB
#   Memory Free  : 14910 MB
#
# ==================================================
# TORCH CUDA MEMORY
# ==================================================
#   Allocated : 0.0 MB
#   Reserved  : 0.0 MB
# ✅ dev_predictions.txt saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage3

# %%
import os
os.system("pip install errant -q")
os.system("python -m spacy download en -q")
print("✅ ERRANT installed!")
# Out:
# ✅ ERRANT installed!

# %%
# ── Cell 11: ERRANT annotation + scoring ──────────────────────────────────────
import os, shutil

print("Running ERRANT annotation on dev predictions...")
ret = os.system(f"errant_parallel -orig {DEV_ORIG} -cor {DEV_PRED} -out {DEV_HYP_M2}")
print(f"errant_parallel exit code: {ret}")

if os.path.exists(DEV_HYP_M2):
    print("✅ dev_hyp.m2 created!")
else:
    print("❌ dev_hyp.m2 not created — check exit code above")
    # Debug: check if input files exist and have content
    for label, path in [("DEV_ORIG", DEV_ORIG), ("DEV_PRED", DEV_PRED)]:
        if os.path.exists(path):
            with open(path) as f:
                lines = sum(1 for _ in f)
            print(f"  {label}: {lines} lines → {path}")
        else:
            print(f"  ❌ {label} missing: {path}")

if not os.path.exists(DEV_HYP_M2):
    raise FileNotFoundError("dev_hyp.m2 not created — fix errant_parallel error above first")

with open(DEV_HYP_M2) as f:
    hyp_count = sum(1 for line in f if line.startswith("S "))
with open(GOLD_M2) as f:
    gold_count = sum(1 for line in f if line.startswith("S "))

print(f"hyp sentences:  {hyp_count}")
print(f"gold sentences: {gold_count}")

if hyp_count != gold_count:
    print("❌ Sentence count mismatch!")
else:
    print("\n========================================")
    print("ERRANT Scores on BEA-2019 Dev Set:")
    print("(Precision / Recall / F0.5)")
    print("========================================")
    result = os.popen(f"errant_compare -hyp {DEV_HYP_M2} -ref {GOLD_M2} 2>&1").read()
    print(result)

# ── Save to Drive ──
shutil.copy(DEV_HYP_M2, os.path.join(EVAL_OUT, "dev_hyp.m2"))
print(f"✅ dev_hyp.m2 saved to Drive: {EVAL_OUT}")
# Out:
# Running ERRANT annotation on dev predictions...
# errant_parallel exit code: 0
# ✅ dev_hyp.m2 created!
# hyp sentences:  4384
# gold sentences: 4384
#
# ========================================
# ERRANT Scores on BEA-2019 Dev Set:
# (Precision / Recall / F0.5)
# ========================================
#
# =========== Span-Based Correction ============
# TP	FP	FN	Prec	Rec	F0.5
# 1504	1116	5957	0.574	0.2016	0.4192
# ==============================================
#
#
# ✅ dev_hyp.m2 saved to Drive: /content/drive/Shareddrives/gec_thesis/gec_thesis/models/eval/mobilebert/stage3
